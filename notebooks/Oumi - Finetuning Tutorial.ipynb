# %% [markdown]
# <a href="https://colab.research.google.com/github/khalilhimura/oumi-explore/blob/main/notebooks/Oumi%20-%20Finetuning%20Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="align-center">
# <a href="https://oumi.ai/"><img src="https://oumi.ai/docs/en/latest/_static/logo/header_logo.png" height="200"></a>
#
# [![Documentation](https://img.shields.io/badge/Documentation-latest-blue.svg)](https://oumi.ai/docs/en/latest/index.html)
# [![Discord](https://img.shields.io/discord/1286348126797430814?label=Discord)](https://discord.gg/oumi)
# [![GitHub Repo stars](https://img.shields.io/github/stars/oumi-ai/oumi)](https://github.com/oumi-ai/oumi)
# </div>
#
# 👋 Welcome to Open Universal Machine Intelligence (Oumi)!
#
# 🚀 Oumi is a fully open-source platform that streamlines the entire lifecycle of foundation models - from [data preparation](https://oumi.ai/docs/en/latest/resources/datasets/datasets.html) and [training](hhttps://oumi.ai/docs/en/latest/user_guides/train/train.html) to [evaluation](https://oumi.ai/docs/en/latest/user_guides/evaluate/evaluate.html) and [deployment](https://oumi.ai/docs/en/latest/user_guides/launch/launch.html). Whether you're developing on a laptop, launching large scale experiments on a cluster, or deploying models in production, Oumi provides the tools and workflows you need.
#
# 🤝 Make sure to join our [Discord community](https://discord.gg/oumi) to get help, share your experiences, and contribute to the project! If you are interested in joining one of the community's open-science efforts, check out our [open collaboration](https://oumi.ai/community) page.
#
# ⭐ If you like Oumi and you would like to support it, please give it a star on [GitHub](https://github.com/oumi-ai/oumi).

# %% [markdown]
# ### Khalil's Comment
# *   In order to run on Colab T4, used SmolLM2 360M instead
# *   Chaged max_steps: 5
# *   As expected, generated code from finetuned model not good
# *   Gave to Gemini to fix

# %% [markdown]
# # Finetuning Overview
#
# In this tutorial, we'll LoRA tune a large language model to produce "thoughts" before producing its output.
#
# We'll use the Oumi framework to streamline the process and achieve high-quality results.
#
# We'll cover the following topics:
# 1. Prerequisites
# 2. Data Preparation & Sanity Checks
# 3. Training Config Preparation
# 4. Launching Training
# 5. Monitoring Progress
# 6. Evaluation
# 7. Analyzing Results
# 8. Inference

# %% [markdown]
# # Prerequisites
# ## Oumi Installation
#
# First, let's install Oumi. You can find more detailed instructions [here](https://oumi.ai/docs/en/latest/get_started/installation.html).
#
# If you have a GPU, you can run the following commands to install Oumi:

# %%
# %pip install uv -q
# !uv pip install oumi[gpu] vllm --no-progress --system
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.2/16.2 MB 72.9 MB/s eta 0:00:00
# Using Python 3.11.11 environment at: /usr
# Resolved 170 packages in 3.71s
# Prepared 76 packages in 8m 41s
# Uninstalled 21 packages in 1.26s
# Installed 76 packages in 779ms
#  + aiofiles==24.1.0
#  + aioresponses==0.7.8
#  + antlr4-python3-runtime==4.9.3
#  + bitsandbytes==0.45.1
#  + colorama==0.4.6
#  + dataproperty==1.1.0
#  + datasets==3.2.0
#  + dill==0.3.8
#  + evaluate==0.4.3
#  + fastapi==0.115.7
#  + fschat==0.2.36
#  - fsspec==2024.10.0
#  + fsspec==2024.9.0
#  + jsonlines==4.0.0
#  + latex2mathml==3.77.0
#  + liger-kernel==0.3.1
#  + lm-eval==0.4.7
#  + markdown2==2.5.3
#  + mbstrdecoder==1.1.4
#  + multiprocess==0.70.16
#  + nh3==0.2.20
#  + ninja==1.11.1.3
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.1.3.1
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.1.105
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.1.105
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.1.105
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.0.2.54
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.2.106
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.4.5.107
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.1.0.106
#  + nvidia-ml-py==12.560.30
#  - nvidia-nccl-cu12==2.21.5
#  + nvidia-nccl-cu12==2.20.5
#  - nvidia-nvtx-cu12==12.4.127
#  + nvidia-nvtx-cu12==12.1.105
#  + omegaconf==2.3.0
#  + oumi==0.1.3
#  + pathvalidate==3.2.3
#  + pendulum==3.0.0
#  - pexpect==4.9.0
#  + pexpect==4.8.0
#  - pillow==11.1.0
#  + pillow==10.3.0
#  + portalocker==3.1.1
#  + pulp==2.9.0
#  + pybind11==2.13.6
#  - pydantic==2.10.6
#  + pydantic==2.9.2
#  - pydantic-core==2.27.2
#  + pydantic-core==2.23.4
#  + pytablewriter==1.2.1
#  + python-dotenv==1.0.1
#  + ray==2.41.0
#  + responses==0.25.6
#  + rouge-score==0.1.2
#  + sacrebleu==2.5.1
#  + shortuuid==1.0.13
#  + shtab==1.7.1
#  + skypilot==0.7.0
#  + sqlitedict==2.1.0
#  + starlette==0.45.3
#  + svgwrite==1.4.3
#  + tabledata==1.3.4
#  + tcolorpy==0.1.7
#  + tiktoken==0.8.0
#  + time-machine==2.16.0
#  - tokenizers==0.21.0
#  + tokenizers==0.20.3
#  - torch==2.5.1+cu124 (from https://download.pytorch.org/whl/cu124/torch-2.5.1%2Bcu124-cp311-cp311-linux_x86_64.whl)
#  + torch==2.4.1
#  + torchdata==0.9.0
#  - torchvision==0.20.1+cu124 (from https://download.pytorch.org/whl/cu124/torchvision-0.20.1%2Bcu124-cp311-cp311-linux_x86_64.whl)
#  + torchvision==0.19.1
#  + tqdm-multiprocess==0.0.11
#  - transformers==4.47.1
#  + transformers==4.45.2
#  - triton==3.1.0
#  + triton==3.0.0
#  + trl==0.11.4
#  + typepy==1.3.4
#  + tyro==0.9.13
#  + uvicorn==0.34.0
#  + vllm==0.1.2
#  + wavedrom==2.0.3.post3
#  + word2number==1.1
#  + xformers==0.0.28.post1
#  + xxhash==3.5.0

# %% [markdown]
# ## Creating our working directory
# For our experiments, we'll use the following folder to save the model, training artifacts, and our working configs.

# %%
from pathlib import Path

tutorial_dir = "finetuning_tutorial"

Path(tutorial_dir).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Setup the environment
#
# We'll need to set the following environment variables:
# - [Optional] HF_TOKEN: Your [HuggingFace](https://huggingface.co/docs/hub/en/security-tokens) token, in case you want to access a private model.
# - [Optional] WANDB_API_KEY: Your [wandb](https://wandb.ai) token, in case you want to log your experiments to wandb.

# %% [markdown]
# # Getting Started
#
#
# ## Data Preparation
# Let's start by checking out our datasets, and seeing what the data looks like. The OpenO1-SFT dataset includes a variety of tasks, including code generation and explanation, with most examples having a "thought" produced prior to the output.

# %%
from oumi.builders import build_tokenizer
from oumi.core.configs import ModelParams
from oumi.datasets import PromptResponseDataset

# Initialize the dataset
tokenizer = build_tokenizer(
    ModelParams(model_name="HuggingFaceTB/SmolLM2-360M-Instruct")
)
dataset = PromptResponseDataset(
    tokenizer=tokenizer,
    hf_dataset_path="O1-OPEN/OpenO1-SFT",
    prompt_column="instruction",
    response_column="output",
)

# Print a few examples
for i in range(3):
    conversation = dataset.conversation(i)
    print(f"Example {i + 1}:")
    for message in conversation.messages:
        print(f"{message.role}: {message.content[:100]}...")  # Truncate for brevity
    print("\n")
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.76k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/801k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# [2025-01-30 15:16:31,667][oumi][rank0][pid:16046][MainThread][INFO]][base_map_dataset.py:68] Creating map dataset (type: PromptResponseDataset) dataset_name: 'O1-OPEN/OpenO1-SFT', dataset_path: 'None'...
# [2025-01-30 15:16:32,982][oumi][rank0][pid:16046][MainThread][INFO]][base_map_dataset.py:472] Dataset Info:
# 	Split: train
# 	Version: 0.0.0
# 	Dataset size: 372897013
# 	Download size: 383545217
# 	Size: 756442230 bytes
# 	Rows: 77685
# 	Columns: ['instruction', 'output']
# [2025-01-30 15:16:34,145][oumi][rank0][pid:16046][MainThread][INFO]][base_map_dataset.py:411] Loaded DataFrame with shape: (77685, 2). Columns:
# instruction    object
# output         object
# dtype: object
# Example 1:
# user: Consider a regular octagon. How many different triangles can be formed if the octagon is placed insi...
# assistant: <Thought>
# Alright, I need to figure out how many different triangles can be formed in a regular octa...
#
#
# Example 2:
# user: Create a Python class that encodes a given number using the Full Kociołek Encryption algorithm. The ...
# assistant: <Thought>
# Alright, I need to create a Python class that implements the Full Kociołek Encryption algo...
#
#
# Example 3:
# user: Write a Python function named `is_valid_binary` that takes in a string as a parameter. The function ...
# assistant: <Thought>
# Alright, I need to write a Python function named `is_valid_binary` that takes a string as ...

# %% [markdown]
# ## Model Preparation
#
# For code generation, we want a model with strong general language understanding and coding capabilities.
#
# We also want a model that is small enough to train and run on a single GPU.
#
# Some good options include:
# - ["microsoft/Phi-3-mini-128k-instruct"](https://huggingface.co/microsoft/Phi-3-mini-128k-instruct)
# - ["google/gemma-2b"](https://huggingface.co/google/gemma-2b)
# - ["Qwen/Qwen2-1.5B-Instruct"](https://huggingface.co/Qwen/Qwen2-1.5B-Instruct)
# - ["meta-llama/Llama-3.2-3B-Instruct"](https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct)
# - ["HuggingFaceTB/SmolLM2-1.7B-Instruct"](https://huggingface.co/HuggingFaceTB/SmolLM2-1.7B-Instruct)
#
#
# For this tutorial, we'll use "HuggingFaceTB/SmolLM2-1.7B-Instruct" as our base model.

# %% [markdown]
# ## Initial Model Responses
#
# Let's see how our model performs on an example prompt.

# %%
# %%writefile $tutorial_dir/infer.yaml
#
# model:
#   model_name: "HuggingFaceTB/SmolLM2-360M-Instruct"
#   trust_remote_code: true
#   torch_dtype_str: "bfloat16"
#
# generation:
#   max_new_tokens: 256
#   batch_size: 1
# Out:
# Overwriting finetuning_tutorial/infer.yaml

# %%
from oumi.core.configs import InferenceConfig
from oumi.infer import infer

config = InferenceConfig.from_yaml(str(Path(tutorial_dir) / "infer.yaml"))

input_text = (
    "Write a Python function to implement the quicksort algorithm. "
    "Please include comments explaining each step."
)

results = infer(config=config, inputs=[input_text])

print(results[0])
# Out:
# [2025-01-30 15:17:15,186][oumi][rank0][pid:16046][MainThread][WARNING]][infer.py:19] No inference engine specified. Using the default 'native' engine.
# [2025-01-30 15:17:15,187][oumi][rank0][pid:16046][MainThread][INFO]][models.py:185] Building model using device_map: auto (DeviceRankInfo(world_size=1, rank=0, local_world_size=1, local_rank=0))...
# [2025-01-30 15:17:15,282][oumi][rank0][pid:16046][MainThread][INFO]][models.py:255] Using model class: <class 'transformers.models.auto.modeling_auto.AutoModelForCausalLM'> to instantiate model.
# model.safetensors:   0%|          | 0.00/724M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# [2025-01-30 15:17:34,433][oumi][rank0][pid:16046][MainThread][INFO]][native_text_inference_engine.py:111] Setting EOS token id to `2`
# conversation_id=None messages=[USER: Write a Python function to implement the quicksort algorithm. Please include comments explaining each step., ASSISTANT: ```python
# def quicksort(arr):
#     # Base case: If the array is empty or contains only one element, return it as is
#     if len(arr) <= 1:
#         return arr
#
#     # Choose a pivot element
#     pivot = arr[len(arr) // 2]
#
#     # Partition the array around the pivot
#     left = [x for x in arr if x < pivot]
#     middle = [x for x in arr if x == pivot]
#     right = [x for x in arr if x > pivot]
#
#     # Recursively sort the left and right partitions
#     quicksort(left)
#     quicksort(right)
#
#     # Combine the sorted partitions
#     return middle
# ```
#
# This quicksort function implements the standard quicksort algorithm. It first checks if the input array is empty or has only one element, in which case it returns the array as is. Then, it chooses a pivot element from the array and partitions the array around it. The left partition contains all elements less than the pivot, the middle partition contains all elements equal to the pivot, and the right partition contains all elements greater than the pivot. The function then recursively sorts the left and right partitions and combines the sorted partitions.] metadata={}

# %%
# !pip install --upgrade vllm
# Out:
# Requirement already satisfied: vllm in /usr/local/lib/python3.11/dist-packages (0.7.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from vllm) (6.1.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from vllm) (0.2.0)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (1.26.4)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from vllm) (4.67.1)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.11/dist-packages (from vllm) (1.0.4)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from vllm) (9.0.0)
# Requirement already satisfied: transformers>=4.45.2 in /usr/local/lib/python3.11/dist-packages (from vllm) (4.48.1)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.21.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from vllm) (5.29.3)
# Requirement already satisfied: fastapi!=0.113.*,!=0.114.0,>=0.107.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.115.7)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from vllm) (3.11.11)
# Requirement already satisfied: openai>=1.52.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (1.60.2)
# Requirement already satisfied: uvicorn[standard] in /usr/local/lib/python3.11/dist-packages (from vllm) (0.34.0)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.10.6)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.21.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from vllm) (10.4.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (7.0.2)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.7.0)
# Requirement already satisfied: lm-format-enforcer<0.11,>=0.10.9 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.10.9)
# Requirement already satisfied: outlines==0.1.11 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.1.11)
# Requirement already satisfied: lark==1.2.2 in /usr/local/lib/python3.11/dist-packages (from vllm) (1.2.2)
# Requirement already satisfied: xgrammar>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.1.11)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.11/dist-packages (from vllm) (4.12.2)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (3.17.0)
# Requirement already satisfied: partial-json-parser in /usr/local/lib/python3.11/dist-packages (from vllm) (0.2.1.1.post5)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.11/dist-packages (from vllm) (26.2.1)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.11/dist-packages (from vllm) (0.19.0)
# Requirement already satisfied: gguf==0.10.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.10.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from vllm) (8.6.1)
# Requirement already satisfied: mistral_common>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from mistral_common[opencv]>=1.5.0->vllm) (1.5.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from vllm) (6.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from vllm) (0.8.0)
# Requirement already satisfied: compressed-tensors==0.9.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.9.0)
# Requirement already satisfied: depyf==0.18.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.18.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from vllm) (3.1.1)
# Requirement already satisfied: ray>=2.9 in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (2.41.0)
# Requirement already satisfied: nvidia-ml-py>=12.560.30 in /usr/local/lib/python3.11/dist-packages (from vllm) (12.570.86)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.5.1)
# Requirement already satisfied: torchvision==0.20.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.20.1)
# Requirement already satisfied: xformers==0.0.28.post3 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.0.28.post3)
# Requirement already satisfied: astor in /usr/local/lib/python3.11/dist-packages (from depyf==0.18.0->vllm) (0.8.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from depyf==0.18.0->vllm) (0.3.9)
# Requirement already satisfied: interegular in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (0.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (3.1.5)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (1.6.0)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (5.6.3)
# Requirement already satisfied: referencing in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (0.36.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (4.23.0)
# Requirement already satisfied: pycountry in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (24.6.1)
# Requirement already satisfied: airportsdata in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (20241001)
# Requirement already satisfied: outlines_core==0.1.26 in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (0.1.26)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1->vllm) (1.3.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi!=0.113.*,!=0.114.0,>=0.107.0->vllm) (0.45.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lm-format-enforcer<0.11,>=0.10.9->vllm) (24.2)
# Requirement already satisfied: opencv-python-headless<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mistral_common[opencv]>=1.5.0->vllm) (4.11.0.86)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->vllm) (2.27.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (8.1.8)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (1.1.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (1.5.0)
# Requirement already satisfied: aiohttp-cors in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (0.7.0)
# Requirement already satisfied: colorful in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (0.5.6)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (0.11.4)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (20.29.1)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (0.4.0)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (1.70.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (25.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (2024.12.14)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.6.0->vllm) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.19.1->vllm) (0.28.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.45.2->vllm) (0.5.2)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.11/dist-packages (from xgrammar>=0.1.6->vllm) (2.13.6)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from xgrammar>=0.1.6->vllm) (8.3.4)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->vllm) (3.21.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm) (0.14.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm) (14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.52.0->vllm) (1.0.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm) (0.22.3)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default]>=2.9->vllm) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default]>=2.9->vllm) (4.3.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->outlines==0.1.11->vllm) (3.0.2)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default]>=2.9->vllm) (0.1.3)
# Requirement already satisfied: six~=1.16 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default]>=2.9->vllm) (1.17.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default]>=2.9->vllm) (2.24.1)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->xgrammar>=0.1.6->vllm) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->xgrammar>=0.1.6->vllm) (1.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open->ray[default]>=2.9->vllm) (1.17.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (2.38.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (0.6.1)

# %%
# !uv pip install --upgrade --force-reinstall --system vllm
# Out:
# Streaming output truncated to the last 5000 lines.
# msgspec    ------------------------------ 203.62 KiB/205.74 KiB
# google-auth ------------------------------ 75.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 38.94 KiB/216.49 KiB
# propcache  ------------------------------ 221.93 KiB/225.65 KiB
# frozenlist ------------------------------ 268.43 KiB/268.43 KiB
# psutil     ------------------------------ 189.90 KiB/280.74 KiB
# protobuf   ------------------------------ 172.91 KiB/312.18 KiB
# pytest     ------------------------------ 123.43 KiB/335.04 KiB
# outlines-core ------------------------------ 306.07 KiB/335.22 KiB
# yarl       ------------------------------ 316.17 KiB/336.08 KiB
# jiter      ------------------------------ 270.71 KiB/337.45 KiB
# blake3     ------------------------------ 302.66 KiB/367.43 KiB
# rpds-py    ------------------------------ 285.56 KiB/372.36 KiB
# xgrammar   ------------------------------ 284.05 KiB/387.59 KiB
# msgpack    ------------------------------ 300.83 KiB/394.21 KiB
# pydantic   ------------------------------ 94.44 KiB/421.58 KiB
# watchfiles ------------------------------ 286.91 KiB/441.97 KiB
# openai     ------------------------------ 62.91 KiB/445.42 KiB
# httptools  ------------------------------ 286.11 KiB/449.01 KiB
# safetensors ------------------------------ 271.11 KiB/451.15 KiB
# ⠹ Preparing packages... (17/131)
# websockets ------------------------------ 32.00 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# msgspec    ------------------------------ 203.62 KiB/205.74 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 54.94 KiB/216.49 KiB
# propcache  ------------------------------ 221.93 KiB/225.65 KiB
# psutil     ------------------------------ 205.90 KiB/280.74 KiB
# protobuf   ------------------------------ 188.91 KiB/312.18 KiB
# pytest     ------------------------------ 123.43 KiB/335.04 KiB
# outlines-core ------------------------------ 333.80 KiB/335.22 KiB
# yarl       ------------------------------ 332.17 KiB/336.08 KiB
# jiter      ------------------------------ 286.75 KiB/337.45 KiB
# blake3     ------------------------------ 334.66 KiB/367.43 KiB
# rpds-py    ------------------------------ 317.56 KiB/372.36 KiB
# xgrammar   ------------------------------ 303.47 KiB/387.59 KiB
# msgpack    ------------------------------ 332.83 KiB/394.21 KiB
# pydantic   ------------------------------ 126.33 KiB/421.58 KiB
# watchfiles ------------------------------ 318.91 KiB/441.97 KiB
# openai     ------------------------------ 62.91 KiB/445.42 KiB
# httptools  ------------------------------ 318.11 KiB/449.01 KiB
# safetensors ------------------------------ 303.11 KiB/451.15 KiB
# huggingface-hub ------------------------------ 158.88 KiB/453.19 KiB
# ⠹ Preparing packages... (17/131)
# websockets ------------------------------ 32.00 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# msgspec    ------------------------------ 203.62 KiB/205.74 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 54.94 KiB/216.49 KiB
# propcache  ------------------------------ 221.93 KiB/225.65 KiB
# psutil     ------------------------------ 205.90 KiB/280.74 KiB
# protobuf   ------------------------------ 188.91 KiB/312.18 KiB
# pytest     ------------------------------ 139.43 KiB/335.04 KiB
# outlines-core ------------------------------ 333.80 KiB/335.22 KiB
# yarl       ------------------------------ 336.08 KiB/336.08 KiB
# jiter      ------------------------------ 286.75 KiB/337.45 KiB
# blake3     ------------------------------ 334.66 KiB/367.43 KiB
# rpds-py    ------------------------------ 317.56 KiB/372.36 KiB
# xgrammar   ------------------------------ 303.47 KiB/387.59 KiB
# msgpack    ------------------------------ 332.83 KiB/394.21 KiB
# pydantic   ------------------------------ 126.33 KiB/421.58 KiB
# watchfiles ------------------------------ 318.91 KiB/441.97 KiB
# openai     ------------------------------ 62.91 KiB/445.42 KiB
# httptools  ------------------------------ 318.11 KiB/449.01 KiB
# safetensors ------------------------------ 303.11 KiB/451.15 KiB
# huggingface-hub ------------------------------ 174.88 KiB/453.19 KiB
# ⠹ Preparing packages... (17/131)
# google-api-core ------------------------------     0 B/156.31 KiB
# websockets ------------------------------ 32.00 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# msgspec    ------------------------------ 203.62 KiB/205.74 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 54.94 KiB/216.49 KiB
# propcache  ------------------------------ 225.65 KiB/225.65 KiB
# psutil     ------------------------------ 237.90 KiB/280.74 KiB
# protobuf   ------------------------------ 188.91 KiB/312.18 KiB
# pytest     ------------------------------ 139.43 KiB/335.04 KiB
# yarl       ------------------------------ 336.08 KiB/336.08 KiB
# jiter      ------------------------------ 302.75 KiB/337.45 KiB
# blake3     ------------------------------ 366.66 KiB/367.43 KiB
# rpds-py    ------------------------------ 349.56 KiB/372.36 KiB
# xgrammar   ------------------------------ 332.05 KiB/387.59 KiB
# msgpack    ------------------------------ 364.83 KiB/394.21 KiB
# pydantic   ------------------------------ 126.33 KiB/421.58 KiB
# watchfiles ------------------------------ 350.91 KiB/441.97 KiB
# openai     ------------------------------ 62.91 KiB/445.42 KiB
# httptools  ------------------------------ 334.11 KiB/449.01 KiB
# safetensors ------------------------------ 319.11 KiB/451.15 KiB
# huggingface-hub ------------------------------ 174.88 KiB/453.19 KiB
# ⠹ Preparing packages... (17/131)
# google-api-core ------------------------------     0 B/156.31 KiB
# websockets ------------------------------ 32.00 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# msgspec    ------------------------------ 203.62 KiB/205.74 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 54.94 KiB/216.49 KiB
# propcache  ------------------------------ 225.65 KiB/225.65 KiB
# psutil     ------------------------------ 237.90 KiB/280.74 KiB
# protobuf   ------------------------------ 204.91 KiB/312.18 KiB
# pytest     ------------------------------ 139.43 KiB/335.04 KiB
# yarl       ------------------------------ 336.08 KiB/336.08 KiB
# jiter      ------------------------------ 302.75 KiB/337.45 KiB
# blake3     ------------------------------ 366.66 KiB/367.43 KiB
# rpds-py    ------------------------------ 349.56 KiB/372.36 KiB
# xgrammar   ------------------------------ 332.05 KiB/387.59 KiB
# msgpack    ------------------------------ 364.83 KiB/394.21 KiB
# pydantic   ------------------------------ 126.33 KiB/421.58 KiB
# watchfiles ------------------------------ 350.91 KiB/441.97 KiB
# openai     ------------------------------ 62.91 KiB/445.42 KiB
# httptools  ------------------------------ 334.11 KiB/449.01 KiB
# safetensors ------------------------------ 335.11 KiB/451.15 KiB
# huggingface-hub ------------------------------ 222.88 KiB/453.19 KiB
# ⠹ Preparing packages... (17/131)
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 16.00 KiB/156.31 KiB
# websockets ------------------------------ 48.00 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# msgspec    ------------------------------ 203.62 KiB/205.74 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 54.94 KiB/216.49 KiB
# propcache  ------------------------------ 225.65 KiB/225.65 KiB
# psutil     ------------------------------ 237.90 KiB/280.74 KiB
# protobuf   ------------------------------ 204.91 KiB/312.18 KiB
# pytest     ------------------------------ 139.43 KiB/335.04 KiB
# jiter      ------------------------------ 334.81 KiB/337.45 KiB
# blake3     ------------------------------ 367.43 KiB/367.43 KiB
# rpds-py    ------------------------------ 372.36 KiB/372.36 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# msgpack    ------------------------------ 391.53 KiB/394.21 KiB
# pydantic   ------------------------------ 126.33 KiB/421.58 KiB
# watchfiles ------------------------------ 385.43 KiB/441.97 KiB
# openai     ------------------------------ 62.91 KiB/445.42 KiB
# httptools  ------------------------------ 381.90 KiB/449.01 KiB
# safetensors ------------------------------ 366.93 KiB/451.15 KiB
# huggingface-hub ------------------------------ 222.88 KiB/453.19 KiB
# ⠹ Preparing packages... (17/131)
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 16.00 KiB/156.31 KiB
# websockets ------------------------------ 48.00 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# msgspec    ------------------------------ 203.62 KiB/205.74 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 54.94 KiB/216.49 KiB
# psutil     ------------------------------ 237.90 KiB/280.74 KiB
# protobuf   ------------------------------ 204.91 KiB/312.18 KiB
# pytest     ------------------------------ 171.43 KiB/335.04 KiB
# jiter      ------------------------------ 334.81 KiB/337.45 KiB
# blake3     ------------------------------ 367.43 KiB/367.43 KiB
# rpds-py    ------------------------------ 372.36 KiB/372.36 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# msgpack    ------------------------------ 394.21 KiB/394.21 KiB
# pydantic   ------------------------------ 126.33 KiB/421.58 KiB
# watchfiles ------------------------------ 385.43 KiB/441.97 KiB
# openai     ------------------------------ 62.91 KiB/445.42 KiB
# httptools  ------------------------------ 381.90 KiB/449.01 KiB
# safetensors ------------------------------ 366.93 KiB/451.15 KiB
# huggingface-hub ------------------------------ 222.88 KiB/453.19 KiB
# distlib    ------------------------------ 379.92 KiB/457.98 KiB
# ⠹ Preparing packages... (17/131)
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 16.00 KiB/156.31 KiB
# websockets ------------------------------ 48.00 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# msgspec    ------------------------------ 203.62 KiB/205.74 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 54.94 KiB/216.49 KiB
# psutil     ------------------------------ 237.90 KiB/280.74 KiB
# protobuf   ------------------------------ 204.91 KiB/312.18 KiB
# pytest     ------------------------------ 171.43 KiB/335.04 KiB
# jiter      ------------------------------ 334.81 KiB/337.45 KiB
# rpds-py    ------------------------------ 372.36 KiB/372.36 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# msgpack    ------------------------------ 394.21 KiB/394.21 KiB
# pydantic   ------------------------------ 126.33 KiB/421.58 KiB
# watchfiles ------------------------------ 385.43 KiB/441.97 KiB
# openai     ------------------------------ 62.91 KiB/445.42 KiB
# httptools  ------------------------------ 381.90 KiB/449.01 KiB
# safetensors ------------------------------ 366.93 KiB/451.15 KiB
# huggingface-hub ------------------------------ 222.88 KiB/453.19 KiB
# distlib    ------------------------------ 379.92 KiB/457.98 KiB
# pyyaml     ------------------------------ 382.28 KiB/745.07 KiB
# ⠹ Preparing packages... (17/131)
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 16.00 KiB/156.31 KiB
# websockets ------------------------------ 48.00 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# msgspec    ------------------------------ 203.62 KiB/205.74 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 70.94 KiB/216.49 KiB
# psutil     ------------------------------ 253.90 KiB/280.74 KiB
# protobuf   ------------------------------ 204.91 KiB/312.18 KiB
# pytest     ------------------------------ 171.43 KiB/335.04 KiB
# jiter      ------------------------------ 337.45 KiB/337.45 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# msgpack    ------------------------------ 394.21 KiB/394.21 KiB
# pydantic   ------------------------------ 158.44 KiB/421.58 KiB
# watchfiles ------------------------------ 398.91 KiB/441.97 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# httptools  ------------------------------ 382.11 KiB/449.01 KiB
# safetensors ------------------------------ 382.93 KiB/451.15 KiB
# huggingface-hub ------------------------------ 222.88 KiB/453.19 KiB
# distlib    ------------------------------ 395.92 KiB/457.98 KiB
# pyyaml     ------------------------------ 398.28 KiB/745.07 KiB
# regex      ------------------------------ 382.50 KiB/774.15 KiB
# ⠹ Preparing packages... (17/131)
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 16.00 KiB/156.31 KiB
# websockets ------------------------------ 63.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# msgspec    ------------------------------ 203.62 KiB/205.74 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 70.94 KiB/216.49 KiB
# psutil     ------------------------------ 269.90 KiB/280.74 KiB
# protobuf   ------------------------------ 220.91 KiB/312.18 KiB
# pytest     ------------------------------ 187.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# msgpack    ------------------------------ 394.21 KiB/394.21 KiB
# pydantic   ------------------------------ 158.44 KiB/421.58 KiB
# watchfiles ------------------------------ 398.91 KiB/441.97 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# httptools  ------------------------------ 382.11 KiB/449.01 KiB
# safetensors ------------------------------ 382.93 KiB/451.15 KiB
# huggingface-hub ------------------------------ 222.88 KiB/453.19 KiB
# distlib    ------------------------------ 413.42 KiB/457.98 KiB
# pyyaml     ------------------------------ 398.28 KiB/745.07 KiB
# regex      ------------------------------ 382.50 KiB/774.15 KiB
# pyzmq      ------------------------------ 382.92 KiB/854.05 KiB
# ⠹ Preparing packages... (17/131)
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 16.00 KiB/156.31 KiB
# websockets ------------------------------ 63.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# msgspec    ------------------------------ 203.62 KiB/205.74 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 70.94 KiB/216.49 KiB
# psutil     ------------------------------ 269.90 KiB/280.74 KiB
# protobuf   ------------------------------ 221.96 KiB/312.18 KiB
# pytest     ------------------------------ 187.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# msgpack    ------------------------------ 394.21 KiB/394.21 KiB
# pydantic   ------------------------------ 158.44 KiB/421.58 KiB
# watchfiles ------------------------------ 398.91 KiB/441.97 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# httptools  ------------------------------ 382.11 KiB/449.01 KiB
# safetensors ------------------------------ 382.93 KiB/451.15 KiB
# huggingface-hub ------------------------------ 222.88 KiB/453.19 KiB
# distlib    ------------------------------ 413.42 KiB/457.98 KiB
# pyyaml     ------------------------------ 398.28 KiB/745.07 KiB
# regex      ------------------------------ 382.50 KiB/774.15 KiB
# pyzmq      ------------------------------ 382.92 KiB/854.05 KiB
# ⠹ Preparing packages... (17/131)
# opencensus ------------------------------     0 B/125.22 KiB
# urllib3    ------------------------------ 14.88 KiB/125.36 KiB
# multidict  ------------------------------ 14.88 KiB/125.98 KiB
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 16.00 KiB/156.31 KiB
# websockets ------------------------------ 63.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 70.94 KiB/216.49 KiB
# psutil     ------------------------------ 269.90 KiB/280.74 KiB
# protobuf   ------------------------------ 221.96 KiB/312.18 KiB
# pytest     ------------------------------ 187.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# msgpack    ------------------------------ 394.21 KiB/394.21 KiB
# pydantic   ------------------------------ 158.44 KiB/421.58 KiB
# watchfiles ------------------------------ 419.08 KiB/441.97 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# httptools  ------------------------------ 430.11 KiB/449.01 KiB
# safetensors ------------------------------ 415.11 KiB/451.15 KiB
# huggingface-hub ------------------------------ 222.88 KiB/453.19 KiB
# distlib    ------------------------------ 413.42 KiB/457.98 KiB
# pyyaml     ------------------------------ 415.98 KiB/745.07 KiB
# ⠹ Preparing packages... (17/131)
# opencensus ------------------------------     0 B/125.22 KiB
# urllib3    ------------------------------ 14.88 KiB/125.36 KiB
# multidict  ------------------------------ 14.88 KiB/125.98 KiB
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 16.00 KiB/156.31 KiB
# websockets ------------------------------ 63.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 70.94 KiB/216.49 KiB
# psutil     ------------------------------ 269.90 KiB/280.74 KiB
# protobuf   ------------------------------ 221.96 KiB/312.18 KiB
# pytest     ------------------------------ 187.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# msgpack    ------------------------------ 394.21 KiB/394.21 KiB
# pydantic   ------------------------------ 158.44 KiB/421.58 KiB
# watchfiles ------------------------------ 419.08 KiB/441.97 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# httptools  ------------------------------ 430.11 KiB/449.01 KiB
# safetensors ------------------------------ 415.11 KiB/451.15 KiB
# huggingface-hub ------------------------------ 222.88 KiB/453.19 KiB
# distlib    ------------------------------ 413.42 KiB/457.98 KiB
# pyyaml     ------------------------------ 415.98 KiB/745.07 KiB
# ⠸ Preparing packages... (27/131)
# opencensus ------------------------------     0 B/125.22 KiB
# urllib3    ------------------------------ 14.88 KiB/125.36 KiB
# multidict  ------------------------------ 14.88 KiB/125.98 KiB
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 16.00 KiB/156.31 KiB
# websockets ------------------------------ 63.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 70.94 KiB/216.49 KiB
# psutil     ------------------------------ 269.90 KiB/280.74 KiB
# protobuf   ------------------------------ 221.96 KiB/312.18 KiB
# pytest     ------------------------------ 187.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# pydantic   ------------------------------ 158.44 KiB/421.58 KiB
# watchfiles ------------------------------ 419.08 KiB/441.97 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# httptools  ------------------------------ 430.11 KiB/449.01 KiB
# safetensors ------------------------------ 415.11 KiB/451.15 KiB
# huggingface-hub ------------------------------ 222.88 KiB/453.19 KiB
# distlib    ------------------------------ 413.42 KiB/457.98 KiB
# pyyaml     ------------------------------ 415.98 KiB/745.07 KiB
# regex      ------------------------------ 428.70 KiB/774.15 KiB
# ⠸ Preparing packages... (27/131)
# opencensus ------------------------------     0 B/125.22 KiB
# urllib3    ------------------------------ 14.88 KiB/125.36 KiB
# multidict  ------------------------------ 14.88 KiB/125.98 KiB
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 16.00 KiB/156.31 KiB
# websockets ------------------------------ 63.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# google-auth ------------------------------ 91.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 70.94 KiB/216.49 KiB
# psutil     ------------------------------ 269.90 KiB/280.74 KiB
# protobuf   ------------------------------ 237.96 KiB/312.18 KiB
# pytest     ------------------------------ 187.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# pydantic   ------------------------------ 158.44 KiB/421.58 KiB
# watchfiles ------------------------------ 441.97 KiB/441.97 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# safetensors ------------------------------ 447.11 KiB/451.15 KiB
# huggingface-hub ------------------------------ 238.77 KiB/453.19 KiB
# distlib    ------------------------------ 445.42 KiB/457.98 KiB
# pyyaml     ------------------------------ 463.98 KiB/745.07 KiB
# regex      ------------------------------ 462.50 KiB/774.15 KiB
# pyzmq      ------------------------------ 424.56 KiB/854.05 KiB
# ⠸ Preparing packages... (27/131)
# lark       ------------------------------ 14.92 KiB/108.43 KiB
# dill       ------------------------------ 14.88 KiB/116.62 KiB
# opencensus ------------------------------ 16.00 KiB/125.22 KiB
# urllib3    ------------------------------ 46.88 KiB/125.36 KiB
# multidict  ------------------------------ 14.88 KiB/125.98 KiB
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 16.00 KiB/156.31 KiB
# websockets ------------------------------ 63.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# google-auth ------------------------------ 107.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 70.94 KiB/216.49 KiB
# psutil     ------------------------------ 269.90 KiB/280.74 KiB
# protobuf   ------------------------------ 237.96 KiB/312.18 KiB
# pytest     ------------------------------ 187.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# pydantic   ------------------------------ 174.44 KiB/421.58 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# safetensors ------------------------------ 447.11 KiB/451.15 KiB
# huggingface-hub ------------------------------ 238.77 KiB/453.19 KiB
# distlib    ------------------------------ 445.42 KiB/457.98 KiB
# pyyaml     ------------------------------ 463.98 KiB/745.07 KiB
# regex      ------------------------------ 462.50 KiB/774.15 KiB
# ⠸ Preparing packages... (27/131)
# click      ------------------------------     0 B/95.89 KiB
# lark       ------------------------------ 14.92 KiB/108.43 KiB
# dill       ------------------------------ 14.88 KiB/116.62 KiB
# opencensus ------------------------------ 16.00 KiB/125.22 KiB
# urllib3    ------------------------------ 46.88 KiB/125.36 KiB
# multidict  ------------------------------ 14.88 KiB/125.98 KiB
# charset-normalizer ------------------------------ 14.90 KiB/140.49 KiB
# google-api-core ------------------------------ 32.00 KiB/156.31 KiB
# websockets ------------------------------ 63.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# google-auth ------------------------------ 107.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 83.00 KiB/216.49 KiB
# psutil     ------------------------------ 269.90 KiB/280.74 KiB
# protobuf   ------------------------------ 237.96 KiB/312.18 KiB
# pytest     ------------------------------ 187.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 380.05 KiB/387.59 KiB
# pydantic   ------------------------------ 190.44 KiB/421.58 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# safetensors ------------------------------ 451.15 KiB/451.15 KiB
# huggingface-hub ------------------------------ 238.77 KiB/453.19 KiB
# distlib    ------------------------------ 457.98 KiB/457.98 KiB
# pyyaml     ------------------------------ 479.98 KiB/745.07 KiB
# ⠸ Preparing packages... (27/131)
# click      ------------------------------     0 B/95.89 KiB
# lark       ------------------------------ 14.92 KiB/108.43 KiB
# dill       ------------------------------ 30.88 KiB/116.62 KiB
# opencensus ------------------------------ 16.00 KiB/125.22 KiB
# urllib3    ------------------------------ 46.88 KiB/125.36 KiB
# multidict  ------------------------------ 14.88 KiB/125.98 KiB
# charset-normalizer ------------------------------ 30.90 KiB/140.49 KiB
# google-api-core ------------------------------ 32.00 KiB/156.31 KiB
# websockets ------------------------------ 79.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 62.87 KiB/177.28 KiB
# google-auth ------------------------------ 107.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 99.00 KiB/216.49 KiB
# psutil     ------------------------------ 269.90 KiB/280.74 KiB
# protobuf   ------------------------------ 237.96 KiB/312.18 KiB
# pytest     ------------------------------ 187.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 387.59 KiB/387.59 KiB
# pydantic   ------------------------------ 190.44 KiB/421.58 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# safetensors ------------------------------ 451.15 KiB/451.15 KiB
# huggingface-hub ------------------------------ 238.77 KiB/453.19 KiB
# distlib    ------------------------------ 457.98 KiB/457.98 KiB
# pyyaml     ------------------------------ 479.98 KiB/745.07 KiB
# ⠸ Preparing packages... (27/131)
# anyio      ------------------------------     0 B/93.79 KiB
# compressed-tensors ------------------------------ 14.90 KiB/94.18 KiB
# click      ------------------------------ 16.00 KiB/95.89 KiB
# lark       ------------------------------ 14.92 KiB/108.43 KiB
# dill       ------------------------------ 46.88 KiB/116.62 KiB
# opencensus ------------------------------ 16.00 KiB/125.22 KiB
# urllib3    ------------------------------ 62.88 KiB/125.36 KiB
# multidict  ------------------------------ 14.88 KiB/125.98 KiB
# charset-normalizer ------------------------------ 40.26 KiB/140.49 KiB
# google-api-core ------------------------------ 32.00 KiB/156.31 KiB
# websockets ------------------------------ 79.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 78.85 KiB/177.28 KiB
# google-auth ------------------------------ 107.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 99.00 KiB/216.49 KiB
# psutil     ------------------------------ 280.74 KiB/280.74 KiB
# protobuf   ------------------------------ 253.96 KiB/312.18 KiB
# pytest     ------------------------------ 203.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 387.59 KiB/387.59 KiB
# pydantic   ------------------------------ 190.44 KiB/421.58 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# huggingface-hub ------------------------------ 238.77 KiB/453.19 KiB
# distlib    ------------------------------ 457.98 KiB/457.98 KiB
# ⠸ Preparing packages... (27/131)
# wrapt      ------------------------------ 14.91 KiB/81.25 KiB
# outlines   ------------------------------ 14.91 KiB/85.57 KiB
# jsonschema ------------------------------ 14.88 KiB/86.39 KiB
# anyio      ------------------------------ 14.59 KiB/93.79 KiB
# compressed-tensors ------------------------------ 14.90 KiB/94.18 KiB
# click      ------------------------------ 16.00 KiB/95.89 KiB
# lark       ------------------------------ 30.92 KiB/108.43 KiB
# dill       ------------------------------ 62.88 KiB/116.62 KiB
# opencensus ------------------------------ 16.00 KiB/125.22 KiB
# urllib3    ------------------------------ 74.90 KiB/125.36 KiB
# multidict  ------------------------------ 122.97 KiB/125.98 KiB
# charset-normalizer ------------------------------ 40.26 KiB/140.49 KiB
# google-api-core ------------------------------ 48.00 KiB/156.31 KiB
# websockets ------------------------------ 111.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 78.85 KiB/177.28 KiB
# google-auth ------------------------------ 123.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 99.00 KiB/216.49 KiB
# psutil     ------------------------------ 280.74 KiB/280.74 KiB
# protobuf   ------------------------------ 253.96 KiB/312.18 KiB
# pytest     ------------------------------ 219.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 387.59 KiB/387.59 KiB
# pydantic   ------------------------------ 222.33 KiB/421.58 KiB
# ⠸ Preparing packages... (27/131)
# wrapt      ------------------------------ 14.91 KiB/81.25 KiB
# outlines   ------------------------------ 14.91 KiB/85.57 KiB
# jsonschema ------------------------------ 14.88 KiB/86.39 KiB
# anyio      ------------------------------ 46.59 KiB/93.79 KiB
# compressed-tensors ------------------------------ 14.90 KiB/94.18 KiB
# click      ------------------------------ 16.00 KiB/95.89 KiB
# lark       ------------------------------ 46.92 KiB/108.43 KiB
# dill       ------------------------------ 62.88 KiB/116.62 KiB
# opencensus ------------------------------ 16.00 KiB/125.22 KiB
# urllib3    ------------------------------ 74.90 KiB/125.36 KiB
# multidict  ------------------------------ 122.97 KiB/125.98 KiB
# charset-normalizer ------------------------------ 40.26 KiB/140.49 KiB
# google-api-core ------------------------------ 48.00 KiB/156.31 KiB
# websockets ------------------------------ 111.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 78.85 KiB/177.28 KiB
# google-auth ------------------------------ 123.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 99.00 KiB/216.49 KiB
# protobuf   ------------------------------ 253.96 KiB/312.18 KiB
# pytest     ------------------------------ 219.43 KiB/335.04 KiB
# xgrammar   ------------------------------ 387.59 KiB/387.59 KiB
# pydantic   ------------------------------ 222.33 KiB/421.58 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# ⠸ Preparing packages... (27/131)
# wrapt      ------------------------------ 14.91 KiB/81.25 KiB
# outlines   ------------------------------ 14.91 KiB/85.57 KiB
# jsonschema ------------------------------ 14.88 KiB/86.39 KiB
# anyio      ------------------------------ 46.59 KiB/93.79 KiB
# compressed-tensors ------------------------------ 14.90 KiB/94.18 KiB
# click      ------------------------------ 48.00 KiB/95.89 KiB
# lark       ------------------------------ 46.92 KiB/108.43 KiB
# dill       ------------------------------ 62.88 KiB/116.62 KiB
# opencensus ------------------------------ 16.00 KiB/125.22 KiB
# urllib3    ------------------------------ 74.90 KiB/125.36 KiB
# multidict  ------------------------------ 125.98 KiB/125.98 KiB
# charset-normalizer ------------------------------ 56.26 KiB/140.49 KiB
# google-api-core ------------------------------ 61.61 KiB/156.31 KiB
# websockets ------------------------------ 111.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 78.85 KiB/177.28 KiB
# google-auth ------------------------------ 123.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 99.00 KiB/216.49 KiB
# protobuf   ------------------------------ 253.96 KiB/312.18 KiB
# pytest     ------------------------------ 219.43 KiB/335.04 KiB
# pydantic   ------------------------------ 222.33 KiB/421.58 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# huggingface-hub ------------------------------ 286.88 KiB/453.19 KiB
# ⠸ Preparing packages... (27/131)
# wrapt      ------------------------------ 14.91 KiB/81.25 KiB
# outlines   ------------------------------ 14.91 KiB/85.57 KiB
# jsonschema ------------------------------ 14.88 KiB/86.39 KiB
# anyio      ------------------------------ 46.59 KiB/93.79 KiB
# compressed-tensors ------------------------------ 14.90 KiB/94.18 KiB
# click      ------------------------------ 48.00 KiB/95.89 KiB
# lark       ------------------------------ 46.92 KiB/108.43 KiB
# dill       ------------------------------ 62.88 KiB/116.62 KiB
# opencensus ------------------------------ 16.00 KiB/125.22 KiB
# urllib3    ------------------------------ 74.90 KiB/125.36 KiB
# multidict  ------------------------------ 125.98 KiB/125.98 KiB
# charset-normalizer ------------------------------ 56.26 KiB/140.49 KiB
# google-api-core ------------------------------ 61.61 KiB/156.31 KiB
# websockets ------------------------------ 111.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 78.85 KiB/177.28 KiB
# google-auth ------------------------------ 123.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 99.00 KiB/216.49 KiB
# protobuf   ------------------------------ 253.96 KiB/312.18 KiB
# pytest     ------------------------------ 219.43 KiB/335.04 KiB
# pydantic   ------------------------------ 222.33 KiB/421.58 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# huggingface-hub ------------------------------ 286.88 KiB/453.19 KiB
# ⠸ Preparing packages... (27/131)
# pyasn1     ------------------------------     0 B/81.19 KiB
# wrapt      ------------------------------ 14.91 KiB/81.25 KiB
# outlines   ------------------------------ 30.17 KiB/85.57 KiB
# jsonschema ------------------------------ 14.88 KiB/86.39 KiB
# anyio      ------------------------------ 46.59 KiB/93.79 KiB
# compressed-tensors ------------------------------ 14.90 KiB/94.18 KiB
# click      ------------------------------ 48.00 KiB/95.89 KiB
# lark       ------------------------------ 46.92 KiB/108.43 KiB
# dill       ------------------------------ 78.88 KiB/116.62 KiB
# opencensus ------------------------------ 16.00 KiB/125.22 KiB
# urllib3    ------------------------------ 74.90 KiB/125.36 KiB
# multidict  ------------------------------ 125.98 KiB/125.98 KiB
# charset-normalizer ------------------------------ 133.12 KiB/140.49 KiB
# google-api-core ------------------------------ 77.61 KiB/156.31 KiB
# websockets ------------------------------ 127.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 78.85 KiB/177.28 KiB
# google-auth ------------------------------ 134.73 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 115.00 KiB/216.49 KiB
# protobuf   ------------------------------ 253.96 KiB/312.18 KiB
# pytest     ------------------------------ 219.43 KiB/335.04 KiB
# pydantic   ------------------------------ 222.33 KiB/421.58 KiB
# openai     ------------------------------ 77.24 KiB/445.42 KiB
# ⠼ Preparing packages... (37/131)
# httpx      ------------------------------     0 B/71.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# httpcore   ------------------------------ 16.00 KiB/76.71 KiB
# pyasn1     ------------------------------ 14.88 KiB/81.19 KiB
# wrapt      ------------------------------ 14.91 KiB/81.25 KiB
# outlines   ------------------------------ 30.17 KiB/85.57 KiB
# jsonschema ------------------------------ 14.88 KiB/86.39 KiB
# anyio      ------------------------------ 46.59 KiB/93.79 KiB
# compressed-tensors ------------------------------ 30.90 KiB/94.18 KiB
# click      ------------------------------ 64.00 KiB/95.89 KiB
# lark       ------------------------------ 62.92 KiB/108.43 KiB
# dill       ------------------------------ 78.88 KiB/116.62 KiB
# opencensus ------------------------------ 32.00 KiB/125.22 KiB
# urllib3    ------------------------------ 90.90 KiB/125.36 KiB
# charset-normalizer ------------------------------ 140.49 KiB/140.49 KiB
# google-api-core ------------------------------ 77.61 KiB/156.31 KiB
# websockets ------------------------------ 127.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 78.85 KiB/177.28 KiB
# google-auth ------------------------------ 139.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 115.00 KiB/216.49 KiB
# protobuf   ------------------------------ 265.84 KiB/312.18 KiB
# pytest     ------------------------------ 219.43 KiB/335.04 KiB
# ⠼ Preparing packages... (37/131)
# httpx      ------------------------------     0 B/71.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# httpcore   ------------------------------ 16.00 KiB/76.71 KiB
# pyasn1     ------------------------------ 14.88 KiB/81.19 KiB
# wrapt      ------------------------------ 30.91 KiB/81.25 KiB
# outlines   ------------------------------ 30.17 KiB/85.57 KiB
# jsonschema ------------------------------ 30.88 KiB/86.39 KiB
# anyio      ------------------------------ 62.59 KiB/93.79 KiB
# compressed-tensors ------------------------------ 30.90 KiB/94.18 KiB
# click      ------------------------------ 64.00 KiB/95.89 KiB
# lark       ------------------------------ 62.92 KiB/108.43 KiB
# dill       ------------------------------ 78.88 KiB/116.62 KiB
# opencensus ------------------------------ 32.00 KiB/125.22 KiB
# urllib3    ------------------------------ 90.90 KiB/125.36 KiB
# charset-normalizer ------------------------------ 140.49 KiB/140.49 KiB
# google-api-core ------------------------------ 77.61 KiB/156.31 KiB
# websockets ------------------------------ 143.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 94.85 KiB/177.28 KiB
# google-auth ------------------------------ 155.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 115.00 KiB/216.49 KiB
# protobuf   ------------------------------ 265.84 KiB/312.18 KiB
# pytest     ------------------------------ 219.43 KiB/335.04 KiB
# ⠼ Preparing packages... (37/131)
# httpx      ------------------------------ 16.00 KiB/71.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# httpcore   ------------------------------ 16.00 KiB/76.71 KiB
# pyasn1     ------------------------------ 14.88 KiB/81.19 KiB
# wrapt      ------------------------------ 81.25 KiB/81.25 KiB
# outlines   ------------------------------ 46.17 KiB/85.57 KiB
# jsonschema ------------------------------ 30.88 KiB/86.39 KiB
# anyio      ------------------------------ 62.59 KiB/93.79 KiB
# compressed-tensors ------------------------------ 30.90 KiB/94.18 KiB
# click      ------------------------------ 80.00 KiB/95.89 KiB
# lark       ------------------------------ 62.92 KiB/108.43 KiB
# dill       ------------------------------ 94.88 KiB/116.62 KiB
# opencensus ------------------------------ 32.00 KiB/125.22 KiB
# urllib3    ------------------------------ 90.90 KiB/125.36 KiB
# google-api-core ------------------------------ 77.61 KiB/156.31 KiB
# websockets ------------------------------ 159.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 94.85 KiB/177.28 KiB
# google-auth ------------------------------ 155.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 115.00 KiB/216.49 KiB
# protobuf   ------------------------------ 284.91 KiB/312.18 KiB
# pytest     ------------------------------ 235.43 KiB/335.04 KiB
# pydantic   ------------------------------ 254.33 KiB/421.58 KiB
# ⠼ Preparing packages... (37/131)
# httpx      ------------------------------ 16.00 KiB/71.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# httpcore   ------------------------------ 16.00 KiB/76.71 KiB
# pyasn1     ------------------------------ 14.88 KiB/81.19 KiB
# outlines   ------------------------------ 46.17 KiB/85.57 KiB
# jsonschema ------------------------------ 30.88 KiB/86.39 KiB
# anyio      ------------------------------ 62.59 KiB/93.79 KiB
# compressed-tensors ------------------------------ 30.90 KiB/94.18 KiB
# click      ------------------------------ 80.00 KiB/95.89 KiB
# lark       ------------------------------ 62.92 KiB/108.43 KiB
# dill       ------------------------------ 94.88 KiB/116.62 KiB
# opencensus ------------------------------ 32.00 KiB/125.22 KiB
# urllib3    ------------------------------ 90.90 KiB/125.36 KiB
# google-api-core ------------------------------ 77.61 KiB/156.31 KiB
# websockets ------------------------------ 159.87 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 94.85 KiB/177.28 KiB
# google-auth ------------------------------ 155.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 115.00 KiB/216.49 KiB
# protobuf   ------------------------------ 284.91 KiB/312.18 KiB
# pytest     ------------------------------ 235.43 KiB/335.04 KiB
# pydantic   ------------------------------ 254.33 KiB/421.58 KiB
# openai     ------------------------------ 104.42 KiB/445.42 KiB
# ⠼ Preparing packages... (37/131)
# gguf       ------------------------------ 14.92 KiB/69.91 KiB
# httpx      ------------------------------ 16.00 KiB/71.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# httpcore   ------------------------------ 16.00 KiB/76.71 KiB
# pyasn1     ------------------------------ 30.88 KiB/81.19 KiB
# outlines   ------------------------------ 46.17 KiB/85.57 KiB
# jsonschema ------------------------------ 46.88 KiB/86.39 KiB
# anyio      ------------------------------ 62.59 KiB/93.79 KiB
# compressed-tensors ------------------------------ 30.90 KiB/94.18 KiB
# click      ------------------------------ 95.89 KiB/95.89 KiB
# lark       ------------------------------ 62.92 KiB/108.43 KiB
# dill       ------------------------------ 94.88 KiB/116.62 KiB
# opencensus ------------------------------ 32.00 KiB/125.22 KiB
# urllib3    ------------------------------ 90.90 KiB/125.36 KiB
# google-api-core ------------------------------ 77.61 KiB/156.31 KiB
# websockets ------------------------------ 165.93 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 94.85 KiB/177.28 KiB
# google-auth ------------------------------ 155.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 115.00 KiB/216.49 KiB
# protobuf   ------------------------------ 284.91 KiB/312.18 KiB
# pytest     ------------------------------ 251.43 KiB/335.04 KiB
# pydantic   ------------------------------ 287.69 KiB/421.58 KiB
# ⠼ Preparing packages... (37/131)
# gguf       ------------------------------ 14.92 KiB/69.91 KiB
# httpx      ------------------------------ 16.00 KiB/71.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# httpcore   ------------------------------ 16.00 KiB/76.71 KiB
# pyasn1     ------------------------------ 30.88 KiB/81.19 KiB
# outlines   ------------------------------ 46.17 KiB/85.57 KiB
# jsonschema ------------------------------ 46.88 KiB/86.39 KiB
# anyio      ------------------------------ 62.59 KiB/93.79 KiB
# compressed-tensors ------------------------------ 30.90 KiB/94.18 KiB
# click      ------------------------------ 95.89 KiB/95.89 KiB
# lark       ------------------------------ 62.92 KiB/108.43 KiB
# dill       ------------------------------ 94.88 KiB/116.62 KiB
# opencensus ------------------------------ 32.00 KiB/125.22 KiB
# urllib3    ------------------------------ 90.90 KiB/125.36 KiB
# google-api-core ------------------------------ 77.61 KiB/156.31 KiB
# websockets ------------------------------ 165.93 KiB/165.93 KiB
# pyasn1-modules ------------------------------ 94.85 KiB/177.28 KiB
# google-auth ------------------------------ 155.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 115.00 KiB/216.49 KiB
# protobuf   ------------------------------ 284.91 KiB/312.18 KiB
# pytest     ------------------------------ 251.43 KiB/335.04 KiB
# pydantic   ------------------------------ 287.69 KiB/421.58 KiB
# ⠼ Preparing packages... (37/131)
# gguf       ------------------------------ 30.92 KiB/69.91 KiB
# httpx      ------------------------------ 16.00 KiB/71.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# httpcore   ------------------------------ 16.00 KiB/76.71 KiB
# pyasn1     ------------------------------ 30.88 KiB/81.19 KiB
# outlines   ------------------------------ 46.17 KiB/85.57 KiB
# jsonschema ------------------------------ 46.88 KiB/86.39 KiB
# anyio      ------------------------------ 64.00 KiB/93.79 KiB
# compressed-tensors ------------------------------ 30.90 KiB/94.18 KiB
# click      ------------------------------ 95.89 KiB/95.89 KiB
# lark       ------------------------------ 78.92 KiB/108.43 KiB
# dill       ------------------------------ 94.88 KiB/116.62 KiB
# opencensus ------------------------------ 32.00 KiB/125.22 KiB
# urllib3    ------------------------------ 90.90 KiB/125.36 KiB
# google-api-core ------------------------------ 93.51 KiB/156.31 KiB
# pyasn1-modules ------------------------------ 94.85 KiB/177.28 KiB
# google-auth ------------------------------ 171.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 115.00 KiB/216.49 KiB
# protobuf   ------------------------------ 284.91 KiB/312.18 KiB
# pytest     ------------------------------ 251.43 KiB/335.04 KiB
# pydantic   ------------------------------ 287.69 KiB/421.58 KiB
# openai     ------------------------------ 104.42 KiB/445.42 KiB
# ⠼ Preparing packages... (37/131)
# idna       ------------------------------ 14.88 KiB/68.79 KiB
# gguf       ------------------------------ 46.92 KiB/69.91 KiB
# httpx      ------------------------------ 32.00 KiB/71.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# httpcore   ------------------------------ 16.00 KiB/76.71 KiB
# pyasn1     ------------------------------ 30.88 KiB/81.19 KiB
# outlines   ------------------------------ 46.17 KiB/85.57 KiB
# jsonschema ------------------------------ 46.88 KiB/86.39 KiB
# anyio      ------------------------------ 80.00 KiB/93.79 KiB
# compressed-tensors ------------------------------ 46.90 KiB/94.18 KiB
# click      ------------------------------ 95.89 KiB/95.89 KiB
# lark       ------------------------------ 78.92 KiB/108.43 KiB
# dill       ------------------------------ 94.88 KiB/116.62 KiB
# opencensus ------------------------------ 48.00 KiB/125.22 KiB
# urllib3    ------------------------------ 106.45 KiB/125.36 KiB
# google-api-core ------------------------------ 93.51 KiB/156.31 KiB
# pyasn1-modules ------------------------------ 94.85 KiB/177.28 KiB
# google-auth ------------------------------ 171.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 131.00 KiB/216.49 KiB
# protobuf   ------------------------------ 300.91 KiB/312.18 KiB
# pytest     ------------------------------ 251.43 KiB/335.04 KiB
# pydantic   ------------------------------ 299.85 KiB/421.58 KiB
# ⠼ Preparing packages... (37/131)
# idna       ------------------------------ 14.88 KiB/68.79 KiB
# gguf       ------------------------------ 46.92 KiB/69.91 KiB
# httpx      ------------------------------ 32.00 KiB/71.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# httpcore   ------------------------------ 31.89 KiB/76.71 KiB
# pyasn1     ------------------------------ 30.88 KiB/81.19 KiB
# outlines   ------------------------------ 46.17 KiB/85.57 KiB
# jsonschema ------------------------------ 46.88 KiB/86.39 KiB
# anyio      ------------------------------ 80.00 KiB/93.79 KiB
# compressed-tensors ------------------------------ 46.90 KiB/94.18 KiB
# click      ------------------------------ 95.89 KiB/95.89 KiB
# lark       ------------------------------ 78.92 KiB/108.43 KiB
# dill       ------------------------------ 94.88 KiB/116.62 KiB
# opencensus ------------------------------ 48.00 KiB/125.22 KiB
# urllib3    ------------------------------ 106.45 KiB/125.36 KiB
# google-api-core ------------------------------ 93.51 KiB/156.31 KiB
# pyasn1-modules ------------------------------ 110.85 KiB/177.28 KiB
# google-auth ------------------------------ 171.89 KiB/205.83 KiB
# googleapis-common-protos ------------------------------ 131.00 KiB/216.49 KiB
# protobuf   ------------------------------ 300.91 KiB/312.18 KiB
# ...
# ⠧ Preparing packages... (129/131)
# vllm       ------------------------------ 202.92 MiB/251.89 MiB
# ⠧ Preparing packages... (129/131)
# vllm       ------------------------------ 204.07 MiB/251.89 MiB
# ⠧ Preparing packages... (129/131)
# vllm       ------------------------------ 205.30 MiB/251.89 MiB
# ⠧ Preparing packages... (129/131)
# vllm       ------------------------------ 207.09 MiB/251.89 MiB
# ⠇ Preparing packages... (129/131)
# vllm       ------------------------------ 208.42 MiB/251.89 MiB
# ⠇ Preparing packages... (129/131)
# vllm       ------------------------------ 209.87 MiB/251.89 MiB
# ⠇ Preparing packages... (129/131)
# vllm       ------------------------------ 211.36 MiB/251.89 MiB
# ⠇ Preparing packages... (129/131)
# vllm       ------------------------------ 212.44 MiB/251.89 MiB
# ⠋ Preparing packages... (129/131)
# vllm       ------------------------------ 213.34 MiB/251.89 MiB
# ⠋ Preparing packages... (129/131)
# vllm       ------------------------------ 213.37 MiB/251.89 MiB
# ⠋ Preparing packages... (129/131)
# vllm       ------------------------------ 215.23 MiB/251.89 MiB
# ⠋ Preparing packages... (129/131)
# vllm       ------------------------------ 215.37 MiB/251.89 MiB
# ⠙ Preparing packages... (129/131)
# vllm       ------------------------------ 216.97 MiB/251.89 MiB
# ⠙ Preparing packages... (129/131)
# vllm       ------------------------------ 217.37 MiB/251.89 MiB
# ⠙ Preparing packages... (129/131)
# vllm       ------------------------------ 218.48 MiB/251.89 MiB
# ⠙ Preparing packages... (129/131)
# vllm       ------------------------------ 219.37 MiB/251.89 MiB
# ⠹ Preparing packages... (129/131)
# vllm       ------------------------------ 220.31 MiB/251.89 MiB
# ⠹ Preparing packages... (129/131)
# vllm       ------------------------------ 221.36 MiB/251.89 MiB
# ⠹ Preparing packages... (129/131)
# vllm       ------------------------------ 222.81 MiB/251.89 MiB
# ⠹ Preparing packages... (129/131)
# vllm       ------------------------------ 223.36 MiB/251.89 MiB
# ⠸ Preparing packages... (129/131)
# vllm       ------------------------------ 224.73 MiB/251.89 MiB
# ⠸ Preparing packages... (129/131)
# vllm       ------------------------------ 226.37 MiB/251.89 MiB
# ⠸ Preparing packages... (129/131)
# vllm       ------------------------------ 226.70 MiB/251.89 MiB
# ⠸ Preparing packages... (129/131)
# vllm       ------------------------------ 227.61 MiB/251.89 MiB
# ⠼ Preparing packages... (129/131)
# vllm       ------------------------------ 229.00 MiB/251.89 MiB
# ⠼ Preparing packages... (129/131)
# vllm       ------------------------------ 230.75 MiB/251.89 MiB
# ⠼ Preparing packages... (129/131)
# vllm       ------------------------------ 230.75 MiB/251.89 MiB
# ⠼ Preparing packages... (129/131)
# vllm       ------------------------------ 232.73 MiB/251.89 MiB
# ⠴ Preparing packages... (129/131)
# vllm       ------------------------------ 233.95 MiB/251.89 MiB
# ⠴ Preparing packages... (129/131)
# vllm       ------------------------------ 235.19 MiB/251.89 MiB
# ⠴ Preparing packages... (129/131)
# vllm       ------------------------------ 236.71 MiB/251.89 MiB
# ⠴ Preparing packages... (129/131)
# vllm       ------------------------------ 238.03 MiB/251.89 MiB
# ⠦ Preparing packages... (129/131)
# vllm       ------------------------------ 239.00 MiB/251.89 MiB
# ⠦ Preparing packages... (129/131)
# vllm       ------------------------------ 241.25 MiB/251.89 MiB
# ⠦ Preparing packages... (129/131)
# vllm       ------------------------------ 242.20 MiB/251.89 MiB
# ⠦ Preparing packages... (129/131)
# vllm       ------------------------------ 242.75 MiB/251.89 MiB
# ⠧ Preparing packages... (129/131)
# vllm       ------------------------------ 244.50 MiB/251.89 MiB
# ⠧ Preparing packages... (129/131)
# vllm       ------------------------------ 245.05 MiB/251.89 MiB
# ⠧ Preparing packages... (129/131)
# vllm       ------------------------------ 245.68 MiB/251.89 MiB
# ⠧ Preparing packages... (129/131)
# vllm       ------------------------------ 247.12 MiB/251.89 MiB
# ⠇ Preparing packages... (129/131)
# vllm       ------------------------------ 247.87 MiB/251.89 MiB
# ⠇ Preparing packages... (129/131)
# vllm       ------------------------------ 249.68 MiB/251.89 MiB
# ⠇ Preparing packages... (129/131)
# vllm       ------------------------------ 250.76 MiB/251.89 MiB
# ⠇ Preparing packages... (129/131)
# vllm       ------------------------------ 251.68 MiB/251.89 MiB
# ⠋ Preparing packages... (129/131)
# vllm       ------------------------------ 251.76 MiB/251.89 MiB
# ⠋ Preparing packages... (129/131)
# vllm       ------------------------------ 251.79 MiB/251.89 MiB
# ⠋ Preparing packages... (129/131)
# vllm       ------------------------------ 251.81 MiB/251.89 MiB
# ⠋ Preparing packages... (129/131)
# ⠋ Preparing packages... (129/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠹ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠸ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠼ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠴ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠦ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠧ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠇ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠋ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# ⠙ Preparing packages... (130/131)
# Prepared 131 packages in 34.43s
# Uninstalled 103 packages in 840ms
# Installed 131 packages in 792ms
#  ~ aiohappyeyeballs==2.4.4
#  ~ aiohttp==3.11.11
#  + aiohttp-cors==0.7.0
#  ~ aiosignal==1.3.2
#  + airportsdata==20241001
#  ~ annotated-types==0.7.0
#  - anyio==3.7.1
#  + anyio==4.8.0
#  + astor==0.8.1
#  ~ attrs==25.1.0
#  + blake3==1.0.4
#  ~ cachetools==5.5.1
#  ~ certifi==2024.12.14
#  ~ charset-normalizer==3.4.1
#  ~ click==8.1.8
#  ~ cloudpickle==3.1.1
#  + colorful==0.5.6
#  + compressed-tensors==0.9.0
#  + depyf==0.18.0
#  - dill==0.3.8
#  + dill==0.3.9
#  + diskcache==5.6.3
#  + distlib==0.3.9
#  ~ distro==1.9.0
#  ~ einops==0.8.0
#  ~ fastapi==0.115.7
#  ~ filelock==3.17.0
#  ~ frozenlist==1.5.0
#  - fsspec==2024.9.0
#  + fsspec==2024.12.0
#  + gguf==0.10.0
#  - google-api-core==2.19.2
#  + google-api-core==2.24.1
#  - google-auth==2.27.0
#  + google-auth==2.38.0
#  ~ googleapis-common-protos==1.66.0
#  ~ grpcio==1.70.0
#  ~ h11==0.14.0
#  ~ httpcore==1.0.7
#  + httptools==0.6.4
#  ~ httpx==0.28.1
#  - huggingface-hub==0.27.1
#  + huggingface-hub==0.28.1
#  ~ idna==3.10
#  ~ importlib-metadata==8.6.1
#  ~ iniconfig==2.0.0
#  + interegular==0.3.3
#  ~ jinja2==3.1.5
#  ~ jiter==0.8.2
#  ~ jsonschema==4.23.0
#  ~ jsonschema-specifications==2024.10.1
#  + lark==1.2.2
#  + lm-format-enforcer==0.10.9
#  ~ markupsafe==3.0.2
#  + mistral-common==1.5.2
#  ~ mpmath==1.3.0
#  ~ msgpack==1.1.0
#  + msgspec==0.19.0
#  ~ multidict==6.1.0
#  ~ nest-asyncio==1.6.0
#  ~ networkx==3.4.2
#  ~ numpy==1.26.4
#  - nvidia-cublas-cu12==12.1.3.1
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.1.105
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.1.105
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.1.105
#  + nvidia-cuda-runtime-cu12==12.4.127
#  ~ nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.0.2.54
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.2.106
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.4.5.107
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.1.0.106
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-ml-py==12.560.30
#  + nvidia-ml-py==12.570.86
#  - nvidia-nccl-cu12==2.20.5
#  + nvidia-nccl-cu12==2.21.5
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  - nvidia-nvtx-cu12==12.1.105
#  + nvidia-nvtx-cu12==12.4.127
#  - openai==1.59.9
#  + openai==1.60.2
#  + opencensus==0.11.4
#  + opencensus-context==0.1.3
#  ~ opencv-python-headless==4.11.0.86
#  + outlines==0.1.11
#  + outlines-core==0.1.26
#  ~ packaging==24.2
#  + partial-json-parser==0.2.1.1.post5
#  - pillow==10.3.0
#  + pillow==10.4.0
#  ~ platformdirs==4.3.6
#  ~ pluggy==1.5.0
#  ~ prometheus-client==0.21.1
#  + prometheus-fastapi-instrumentator==7.0.2
#  ~ propcache==0.2.1
#  - proto-plus==1.25.0
#  + proto-plus==1.26.0
#  - protobuf==4.25.6
#  + protobuf==5.29.3
#  - psutil==5.9.5
#  + psutil==6.1.1
#  ~ py-cpuinfo==9.0.0
#  + py-spy==0.4.0
#  ~ pyasn1==0.6.1
#  ~ pyasn1-modules==0.4.1
#  ~ pybind11==2.13.6
#  + pycountry==24.6.1
#  - pydantic==2.9.2
#  + pydantic==2.10.6
#  - pydantic-core==2.23.4
#  + pydantic-core==2.27.2
#  ~ pytest==8.3.4
#  ~ python-dotenv==1.0.1
#  ~ pyyaml==6.0.2
#  - pyzmq==24.0.1
#  + pyzmq==26.2.1
#  ~ ray==2.41.0
#  ~ referencing==0.36.2
#  ~ regex==2024.11.6
#  ~ requests==2.32.3
#  ~ rpds-py==0.22.3
#  ~ rsa==4.9
#  ~ safetensors==0.5.2
#  ~ sentencepiece==0.2.0
#  ~ six==1.17.0
#  ~ smart-open==7.1.0
#  ~ sniffio==1.3.1
#  ~ starlette==0.45.3
#  ~ sympy==1.13.1
#  - tiktoken==0.8.0
#  + tiktoken==0.7.0
#  - tokenizers==0.20.3
#  + tokenizers==0.21.0
#  - torch==2.4.1
#  + torch==2.5.1
#  - torchvision==0.19.1
#  + torchvision==0.20.1
#  ~ tqdm==4.67.1
#  - transformers==4.45.2
#  + transformers==4.48.1
#  - triton==3.0.0
#  + triton==3.1.0
#  ~ typing-extensions==4.12.2
#  ~ urllib3==2.3.0
#  ~ uvicorn==0.34.0
#  + uvloop==0.21.0
#  + virtualenv==20.29.1
#  - vllm==0.1.2
#  + vllm==0.7.0
#  + watchfiles==1.0.4
#  ~ websockets==14.2
#  ~ wrapt==1.17.2
#  - xformers==0.0.28.post1
#  + xformers==0.0.28.post3
#  + xgrammar==0.1.11
#  ~ yarl==1.18.3
#  ~ zipp==3.21.0

# %% [markdown]
# ## Preparing our training experiment

# %% [markdown]
# Let's create a YAML file for our training config:

# %%
# %%writefile $tutorial_dir/train.yaml
#
# model:
#   model_name: "HuggingFaceTB/SmolLM2-360M-Instruct"
#   trust_remote_code: true
#   torch_dtype_str: "bfloat16"
#   tokenizer_pad_token: "<|endoftext|>"
#   device_map: "auto"
#
# data:
#   train:
#     datasets:
#       - dataset_name: "PromptResponseDataset"
#         split: "train"
#         sample_count: 8000
#         dataset_kwargs: {
#           "hf_dataset_path": "O1-OPEN/OpenO1-SFT",
#           "prompt_column": "instruction",
#           "response_column": "output",
#           "assistant_only": true,
#           "instruction_template": "<|im_start|>user\n",
#           "response_template": "<|im_start|>assistant\n",
#         }
#         shuffle: True
#         seed: 42
#     collator_name: "text_with_padding"
#     seed: 42
#
# training:
#   output_dir: "finetuning_tutorial/output"
#
#   # For a single GPU, the following gives us a batch size of 16
#   # If training with multiple GPUs, feel free to reduce gradient_accumulation_steps
#   per_device_train_batch_size: 2
#   gradient_accumulation_steps: 8
#
#   # ***NOTE***
#   # We set it to 10 steps to first verify that it works
#   # Swap to 1500 steps to get more meaningful results.
#   # Note: 1500 steps will take 2-3 hours on a single A100-40GB GPU.
#   max_steps: 5
#   # max_steps: 1500
#
#   learning_rate: 1e-3
#   warmup_ratio: 0.1
#   logging_steps: 10
#   save_steps: 0
#   max_grad_norm: 1
#   weight_decay: 0.01
#
#
#   trainer_type: "TRL_SFT"
#   optimizer: "adamw_torch_fused"
#   enable_gradient_checkpointing: True
#   gradient_checkpointing_kwargs:
#     use_reentrant: False
#   ddp_find_unused_parameters: False
#   dataloader_num_workers: "auto"
#   dataloader_prefetch_factor: 32
#   empty_device_cache_steps: 1
#   use_peft: true
#
# peft:
#   lora_r: 16
#   lora_alpha: 32
#   lora_dropout: 0.00
#   lora_target_modules:
#     - "q_proj"
#     - "k_proj"
#     - "v_proj"
#     - "o_proj"
#     - "gate_proj"
#     - "up_proj"
#     - "down_proj"
# Out:
# Overwriting finetuning_tutorial/train.yaml

# %% [markdown]
# ## Fine-tuning the model

# %% [markdown]
# This will start the fine-tuning process using the Oumi framework. Because we set `max_steps: 5`, this should be very quick. The full fine-tuning process may take a few hours, depending on your GPU.

# %% [markdown]
# ### SINGLE GPU

# %%
# !oumi train -c "$tutorial_dir/train.yaml"
# Out:
# @@@@@@@@@@@@@@@@@@@
# @                 @
# @   @@@@@  @  @   @
# @   @   @  @  @   @
# @   @@@@@  @@@@   @
# @                 @
# @   @@@@@@@   @   @
# @   @  @  @   @   @
# @   @  @  @   @   @
# @                 @
# @@@@@@@@@@@@@@@@@@@
#
# 2025-01-30 15:19:04.947161: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738250344.976368   28188 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738250344.985819   28188 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [2025-01-30 15:19:08,644][oumi][rank0][pid:28188][MainThread][INFO]][distributed.py:546] Setting random seed to 42 on rank 0.
# [2025-01-30 15:19:10,005][oumi][rank0][pid:28188][MainThread][INFO]][torch_utils.py:66] Torch version: 2.5.1+cu124. NumPy version: 1.26.4
# [2025-01-30 15:19:10,013][oumi][rank0][pid:28188][MainThread][INFO]][torch_utils.py:72] CUDA version: 12.4 CuDNN version: 90.1.0
# [2025-01-30 15:19:10,014][oumi][rank0][pid:28188][MainThread][INFO]][torch_utils.py:106] CPU cores: 2 CUDA devices: 1
# device(0)='Tesla T4' Capability: (7, 5) Memory: [Total: 14.74GiB Free: 13.77GiB Allocated: 0.0GiB Cached: 0.0GiB]
# [2025-01-30 15:19:10,018][oumi][rank0][pid:28188][MainThread][INFO]][train.py:133] Oumi version: 0.1.3
# [2025-01-30 15:19:10,021][oumi][rank0][pid:28188][MainThread][INFO]][train.py:144] Resolved 'training.dataloader_num_workers=auto' to 'training.dataloader_num_workers=1'
# [2025-01-30 15:19:10,022][oumi][rank0][pid:28188][MainThread][INFO]][train.py:174] TrainingConfig:
# TrainingConfig(data=DataParams(train=DatasetSplitParams(datasets=[DatasetParams(dataset_name='PromptResponseDataset',
#                                                                                 dataset_path=None,
#                                                                                 subset=None,
#                                                                                 split='train',
#                                                                                 dataset_kwargs={'assistant_only': True,
#                                                                                                 'hf_dataset_path': 'O1-OPEN/OpenO1-SFT',
#                                                                                                 'instruction_template': '<|im_start|>user\n',
#                                                                                                 'prompt_column': 'instruction',
#                                                                                                 'response_column': 'output',
#                                                                                                 'response_template': '<|im_start|>assistant\n'},
#                                                                                 sample_count=8000,
#                                                                                 mixture_proportion=None,
#                                                                                 shuffle=True,
#                                                                                 seed=42,
#                                                                                 shuffle_buffer_size=1000,
#                                                                                 trust_remote_code=False,
#                                                                                 transform_num_workers=None)],
#                                                         collator_name='text_with_padding',
#                                                         pack=False,
#                                                         stream=False,
#                                                         target_col=None,
#                                                         mixture_strategy='first_exhausted',
#                                                         seed=42,
#                                                         use_async_dataset=False,
#                                                         use_torchdata=None),
#                                test=DatasetSplitParams(datasets=[],
#                                                        collator_name=None,
#                                                        pack=False,
#                                                        stream=False,
#                                                        target_col=None,
#                                                        mixture_strategy='first_exhausted',
#                                                        seed=None,
#                                                        use_async_dataset=False,
#                                                        use_torchdata=None),
#                                validation=DatasetSplitParams(datasets=[],
#                                                              collator_name=None,
#                                                              pack=False,
#                                                              stream=False,
#                                                              target_col=None,
#                                                              mixture_strategy='first_exhausted',
#                                                              seed=None,
#                                                              use_async_dataset=False,
#                                                              use_torchdata=None)),
#                model=ModelParams(model_name='HuggingFaceTB/SmolLM2-360M-Instruct',
#                                  adapter_model=None,
#                                  tokenizer_name=None,
#                                  tokenizer_pad_token='<|endoftext|>',
#                                  tokenizer_kwargs={},
#                                  model_max_length=None,
#                                  load_pretrained_weights=True,
#                                  trust_remote_code=True,
#                                  torch_dtype_str='bfloat16',
#                                  compile=False,
#                                  chat_template=None,
#                                  attn_implementation=None,
#                                  device_map='auto',
#                                  model_kwargs={},
#                                  enable_liger_kernel=False,
#                                  shard_for_eval=False,
#                                  freeze_layers=[]),
#                training=TrainingParams(use_peft=True,
#                                        trainer_type=<TrainerType.TRL_SFT: 'trl_sft'>,
#                                        enable_gradient_checkpointing=True,
#                                        gradient_checkpointing_kwargs={'use_reentrant': False},
#                                        output_dir='finetuning_tutorial/output',
#                                        per_device_train_batch_size=2,
#                                        per_device_eval_batch_size=8,
#                                        gradient_accumulation_steps=8,
#                                        max_steps=5,
#                                        num_train_epochs=3,
#                                        save_epoch=False,
#                                        save_steps=0,
#                                        save_final_model=True,
#                                        seed=42,
#                                        run_name=None,
#                                        metrics_function=None,
#                                        log_level='info',
#                                        dep_log_level='warning',
#                                        enable_wandb=False,
#                                        enable_tensorboard=True,
#                                        logging_strategy='steps',
#                                        logging_dir=None,
#                                        logging_steps=10,
#                                        logging_first_step=False,
#                                        eval_strategy='no',
#                                        eval_steps=500,
#                                        learning_rate=0.001,
#                                        lr_scheduler_type='linear',
#                                        lr_scheduler_kwargs={},
#                                        warmup_ratio=0.1,
#                                        warmup_steps=None,
#                                        optimizer='adamw_torch_fused',
#                                        weight_decay=0.01,
#                                        adam_beta1=0.9,
#                                        adam_beta2=0.999,
#                                        adam_epsilon=1e-08,
#                                        sgd_momentum=0.0,
#                                        mixed_precision_dtype=<MixedPrecisionDtype.NONE: 'none'>,
#                                        compile=False,
#                                        include_performance_metrics=False,
#                                        include_alternative_mfu_metrics=False,
#                                        log_model_summary=False,
#                                        resume_from_checkpoint=None,
#                                        try_resume_from_last_checkpoint=False,
#                                        dataloader_num_workers=1,
#                                        dataloader_prefetch_factor=32,
#                                        dataloader_main_process_only=None,
#                                        ddp_find_unused_parameters=False,
#                                        max_grad_norm=1.0,
#                                        trainer_kwargs={},
#                                        profiler=ProfilerParams(save_dir=None,
#                                                                enable_cpu_profiling=False,
#                                                                enable_cuda_profiling=False,
#                                                                record_shapes=False,
#                                                                profile_memory=False,
#                                                                with_stack=False,
#                                                                with_flops=False,
#                                                                with_modules=False,
#                                                                row_limit=50,
#                                                                schedule=ProfilerScheduleParams(enable_schedule=False,
#                                                                                                wait=0,
#                                                                                                warmup=1,
#                                                                                                active=3,
#                                                                                                repeat=1,
#                                                                                                skip_first=1)),
#                                        telemetry=TelemetryParams(telemetry_dir='telemetry',
#                                                                  collect_telemetry_for_all_ranks=False,
#                                                                  track_gpu_temperature=False),
#                                        empty_device_cache_steps=1,
#                                        nccl_default_timeout_minutes=None),
#                peft=PeftParams(lora_r=16,
#                                lora_alpha=32,
#                                lora_dropout=0.0,
#                                lora_target_modules=['q_proj',
#                                                     'k_proj',
#                                                     'v_proj',
#                                                     'o_proj',
#                                                     'gate_proj',
#                                                     'up_proj',
#                                                     'down_proj'],
#                                lora_modules_to_save=None,
#                                lora_bias='none',
#                                lora_init_weights=<LoraWeightInitialization.DEFAULT: 'default'>,
#                                lora_task_type=<TaskType.CAUSAL_LM: 'CAUSAL_LM'>,
#                                q_lora=False,
#                                q_lora_bits=4,
#                                bnb_4bit_quant_type='fp4',
#                                use_bnb_nested_quant=False,
#                                bnb_4bit_quant_storage='uint8',
#                                bnb_4bit_compute_dtype='float32',
#                                peft_save_mode=<PeftSaveMode.ADAPTER_ONLY: 'adapter_only'>),
#                fsdp=FSDPParams(enable_fsdp=False,
#                                sharding_strategy=<ShardingStrategy.FULL_SHARD: 'FULL_SHARD'>,
#                                cpu_offload=False,
#                                mixed_precision=None,
#                                backward_prefetch=<BackwardPrefetch.BACKWARD_PRE: 'BACKWARD_PRE'>,
#                                forward_prefetch=False,
#                                use_orig_params=None,
#                                state_dict_type=<StateDictType.FULL_STATE_DICT: 'FULL_STATE_DICT'>,
#                                auto_wrap_policy=<AutoWrapPolicy.NO_WRAP: 'NO_WRAP'>,
#                                min_num_params=100000,
#                                transformer_layer_cls=None,
#                                sync_module_states=True))
# [2025-01-30 15:19:10,351][oumi][rank0][pid:28188][MainThread][INFO]][models.py:185] Building model using device_map: auto (DeviceRankInfo(world_size=1, rank=0, local_world_size=1, local_rank=0))...
# [2025-01-30 15:19:10,352][oumi][rank0][pid:28188][MainThread][INFO]][models.py:255] Using model class: <class 'transformers.models.auto.modeling_auto.AutoModelForCausalLM'> to instantiate model.
# INFO:accelerate.utils.modeling:We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# [2025-01-30 15:19:14,286][oumi][rank0][pid:28188][MainThread][INFO]][train.py:226] Building PEFT model...
# [2025-01-30 15:19:14,862][oumi][rank0][pid:28188][MainThread][INFO]][base_map_dataset.py:68] Creating map dataset (type: PromptResponseDataset) dataset_name: 'O1-OPEN/OpenO1-SFT', dataset_path: 'None'...
# [2025-01-30 15:19:14,863][oumi][rank0][pid:28188][MainThread][WARNING]][base_sft_dataset.py:251] Response template '<|im_start|>assistant
# ' contains leading or trailing whitespaces. These will be ignored.
# [2025-01-30 15:19:14,863][oumi][rank0][pid:28188][MainThread][WARNING]][base_sft_dataset.py:267] Instruction template '<|im_start|>user
# ' contains leading or trailing whitespaces. These will be ignored.
# [2025-01-30 15:19:16,213][oumi][rank0][pid:28188][MainThread][INFO]][base_map_dataset.py:472] Dataset Info:
# 	Split: train
# 	Version: 0.0.0
# 	Dataset size: 372897013
# 	Download size: 383545217
# 	Size: 756442230 bytes
# 	Rows: 77685
# 	Columns: ['instruction', 'output']
# [2025-01-30 15:19:17,291][oumi][rank0][pid:28188][MainThread][INFO]][base_map_dataset.py:411] Loaded DataFrame with shape: (77685, 2). Columns:
# instruction    object
# output         object
# dtype: object
# [2025-01-30 15:19:17,388][oumi][rank0][pid:28188][MainThread][INFO]][base_map_dataset.py:297] PromptResponseDataset: features=dict_keys(['input_ids', 'attention_mask', 'labels'])
# Generating train split: 77685 examples [06:27, 200.29 examples/s]
# [2025-01-30 15:25:46,398][oumi][rank0][pid:28188][MainThread][INFO]][base_map_dataset.py:361] Finished transforming dataset (PromptResponseDataset)! Speed: 199.70 examples/sec. Examples: 77685. Duration: 389.0 sec. Transform workers: 1.
# Flattening the indices: 100% 77685/77685 [00:27<00:00, 2856.35 examples/s]
# [2025-01-30 15:26:14,071][oumi][rank0][pid:28188][MainThread][INFO]][torch_profiler_utils.py:150] PROF: Torch Profiler disabled!
# [2025-01-30 15:26:14,114][oumi][rank0][pid:28188][MainThread][INFO]][training.py:49] SFTConfig(output_dir='finetuning_tutorial/output',
#           overwrite_output_dir=False,
#           do_train=False,
#           do_eval=False,
#           do_predict=False,
#           eval_strategy=<IntervalStrategy.NO: 'no'>,
#           prediction_loss_only=False,
#           per_device_train_batch_size=2,
#           per_device_eval_batch_size=8,
#           per_gpu_train_batch_size=None,
#           per_gpu_eval_batch_size=None,
#           gradient_accumulation_steps=8,
#           eval_accumulation_steps=None,
#           eval_delay=0,
#           torch_empty_cache_steps=1,
#           learning_rate=0.001,
#           weight_decay=0.01,
#           adam_beta1=0.9,
#           adam_beta2=0.999,
#           adam_epsilon=1e-08,
#           max_grad_norm=1.0,
#           num_train_epochs=3,
#           max_steps=5,
#           lr_scheduler_type=<SchedulerType.LINEAR: 'linear'>,
#           lr_scheduler_kwargs={},
#           warmup_ratio=0.1,
#           warmup_steps=0,
#           log_level='warning',
#           log_level_replica='warning',
#           log_on_each_node=True,
#           logging_dir='finetuning_tutorial/output/runs/Jan30_15-26-14_40f8d435f4cc',
#           logging_strategy=<IntervalStrategy.STEPS: 'steps'>,
#           logging_first_step=False,
#           logging_steps=10,
#           logging_nan_inf_filter=True,
#           save_strategy=<SaveStrategy.NO: 'no'>,
#           save_steps=0,
#           save_total_limit=None,
#           save_safetensors=True,
#           save_on_each_node=False,
#           save_only_model=False,
#           restore_callback_states_from_checkpoint=False,
#           no_cuda=False,
#           use_cpu=False,
#           use_mps_device=False,
#           seed=42,
#           data_seed=None,
#           jit_mode_eval=False,
#           use_ipex=False,
#           bf16=False,
#           fp16=False,
#           fp16_opt_level='O1',
#           half_precision_backend='auto',
#           bf16_full_eval=False,
#           fp16_full_eval=False,
#           tf32=None,
#           local_rank=0,
#           ddp_backend=None,
#           tpu_num_cores=None,
#           tpu_metrics_debug=False,
#           debug=[],
#           dataloader_drop_last=False,
#           eval_steps=500,
#           dataloader_num_workers=1,
#           dataloader_prefetch_factor=32,
#           past_index=-1,
#           run_name='finetuning_tutorial/output',
#           disable_tqdm=False,
#           remove_unused_columns=True,
#           label_names=None,
#           load_best_model_at_end=False,
#           metric_for_best_model=None,
#           greater_is_better=None,
#           ignore_data_skip=False,
#           fsdp=[],
#           fsdp_min_num_params=0,
#           fsdp_config={'min_num_params': 0,
#                        'xla': False,
#                        'xla_fsdp_grad_ckpt': False,
#                        'xla_fsdp_v2': False},
#           fsdp_transformer_layer_cls_to_wrap=None,
#           accelerator_config=AcceleratorConfig(split_batches=False,
#                                                dispatch_batches=None,
#                                                even_batches=True,
#                                                use_seedable_sampler=True,
#                                                non_blocking=False,
#                                                gradient_accumulation_kwargs=None,
#                                                use_configured_state=False),
#           deepspeed=None,
#           label_smoothing_factor=0.0,
#           optim=<OptimizerNames.ADAMW_TORCH_FUSED: 'adamw_torch_fused'>,
#           optim_args=None,
#           adafactor=False,
#           group_by_length=False,
#           length_column_name='length',
#           report_to=['tensorboard'],
#           ddp_find_unused_parameters=False,
#           ddp_bucket_cap_mb=None,
#           ddp_broadcast_buffers=None,
#           dataloader_pin_memory=True,
#           dataloader_persistent_workers=False,
#           skip_memory_metrics=True,
#           use_legacy_prediction_loop=False,
#           push_to_hub=False,
#           resume_from_checkpoint=None,
#           hub_model_id=None,
#           hub_strategy=<HubStrategy.EVERY_SAVE: 'every_save'>,
#           hub_token=None,
#           hub_private_repo=None,
#           hub_always_push=False,
#           gradient_checkpointing=True,
#           gradient_checkpointing_kwargs={'use_reentrant': False},
#           include_inputs_for_metrics=False,
#           include_for_metrics=[],
#           eval_do_concat_batches=True,
#           fp16_backend='auto',
#           evaluation_strategy=None,
#           push_to_hub_model_id=None,
#           push_to_hub_organization=None,
#           push_to_hub_token=None,
#           mp_parameters='',
#           auto_find_batch_size=False,
#           full_determinism=False,
#           torchdynamo=None,
#           ray_scope='last',
#           ddp_timeout=1800,
#           torch_compile=False,
#           torch_compile_backend=None,
#           torch_compile_mode=None,
#           dispatch_batches=None,
#           split_batches=None,
#           include_tokens_per_second=False,
#           include_num_input_tokens_seen=False,
#           neftune_noise_alpha=None,
#           optim_target_modules=None,
#           batch_eval_metrics=False,
#           eval_on_start=False,
#           use_liger_kernel=False,
#           eval_use_gather_object=False,
#           average_tokens_across_devices=False,
#           dataset_text_field=None,
#           packing=False,
#           max_seq_length=None,
#           dataset_num_proc=None,
#           dataset_batch_size=1000,
#           model_init_kwargs=None,
#           dataset_kwargs=None,
#           eval_packing=None,
#           num_of_sequences=1024,
#           chars_per_token=3.6,
#           use_liger=False)
# /usr/local/lib/python3.11/dist-packages/trl/trainer/sft_trainer.py:292: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/trl/trainer/sft_trainer.py:401: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `SFTTrainer.__init__`. Use `processing_class` instead.
#   super().__init__(
# [2025-01-30 15:26:14,183][oumi][rank0][pid:28188][MainThread][INFO]][device_utils.py:283] GPU Metrics Before Training: GPU runtime info: NVidiaGpuRuntimeInfo(device_index=0, device_count=1, used_memory_mb=2037.0, temperature=69, fan_speed=None, fan_speeds=None, power_usage_watts=29.709, power_limit_watts=70.0, gpu_utilization=0, memory_utilization=0, performance_state=0, clock_speed_graphics=585, clock_speed_sm=585, clock_speed_memory=5000).
# [2025-01-30 15:26:14,183][oumi][rank0][pid:28188][MainThread][INFO]][train.py:312] Training init time: 424.179s
# [2025-01-30 15:26:14,183][oumi][rank0][pid:28188][MainThread][INFO]][train.py:313] Starting training... (TrainerType.TRL_SFT, transformers: 4.48.1)
# {'train_runtime': 261.5632, 'train_samples_per_second': 0.306, 'train_steps_per_second': 0.019, 'train_loss': 0.9875136375427246, 'epoch': 0.01}
# 100% 5/5 [04:21<00:00, 52.31s/it]
# [2025-01-30 15:30:36,409][oumi][rank0][pid:28188][MainThread][INFO]][train.py:320] Training is Complete.
# [2025-01-30 15:30:36,415][oumi][rank0][pid:28188][MainThread][INFO]][device_utils.py:283] GPU Metrics After Training: GPU runtime info: NVidiaGpuRuntimeInfo(device_index=0, device_count=1, used_memory_mb=6229.0, temperature=76, fan_speed=None, fan_speeds=None, power_usage_watts=42.34, power_limit_watts=70.0, gpu_utilization=63, memory_utilization=44, performance_state=0, clock_speed_graphics=1575, clock_speed_sm=1575, clock_speed_memory=5000).
# [2025-01-30 15:30:36,416][oumi][rank0][pid:28188][MainThread][INFO]][torch_utils.py:117] Peak GPU memory usage: 10.17 GB
# [2025-01-30 15:30:36,416][oumi][rank0][pid:28188][MainThread][INFO]][train.py:327] Saving final state...
# [2025-01-30 15:30:36,416][oumi][rank0][pid:28188][MainThread][INFO]][train.py:332] Saving final model...
# [2025-01-30 15:30:36,974][oumi][rank0][pid:28188][MainThread][INFO]][hf_trainer.py:102] Model has been saved at finetuning_tutorial/output
# [2025-01-30 15:30:36,974][oumi][rank0][pid:28188][MainThread][INFO]][train.py:339]
#
# » We're always looking for feedback. What's one thing we can improve? https://oumi.ai/feedback

# %%
 # %pip install datasets --upgrade
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.1 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.3 MB/s eta 0:00:00
# Installing collected packages: fsspec, dill
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.12.0
#     Uninstalling fsspec-2024.12.0:
#       Successfully uninstalled fsspec-2024.12.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.9
#     Uninstalling dill-0.3.9:
#       Successfully uninstalled dill-0.3.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# oumi 0.1.3 requires pillow<10.4,>=10.3.0, but you have pillow 10.4.0 which is incompatible.
# oumi 0.1.3 requires pydantic<2.10,>=2.9.2, but you have pydantic 2.10.6 which is incompatible.
# oumi 0.1.3 requires torch<2.5.0,>=2.4.0, but you have torch 2.5.1 which is incompatible.
# oumi 0.1.3 requires torchvision<0.20,>=0.19.0, but you have torchvision 0.20.1 which is incompatible.
# oumi 0.1.3 requires transformers<4.46,>=4.45.2, but you have transformers 4.48.1 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed dill-0.3.8 fsspec-2024.9.0

# %% [markdown]
# ### MULTI-GPU

# %%
# !oumi distributed torchrun -m oumi train -c "$tutorial_dir/train.yaml"

# %% [markdown]
# ## Evaluation

# %% [markdown]
# As an example, let's create an evaluation configuration file!
#
# **Note:** Since we've finetuned our model to produce thoughts before answering, it's very likely to do worse on most evals out-of-the-box.
#
# Many evals do not allow models to decode and thus don't take advantage of things like inference-time reasoning.

# %%
# %%writefile $tutorial_dir/eval.yaml
#
# model:
#   model_name: "finetuning_tutorial/output"
#   torch_dtype_str: "bfloat16"
#
# tasks:
#   - evaluation_platform: lm_harness
#     task_name: mmlu_college_computer_science
#
# output_dir: "finetuning_tutorial/output/evaluation"
# generation:
#   batch_size: null # This will let LM HARNESS find the maximum possible batch size.
# Out:
# Writing finetuning_tutorial/eval.yaml

# %%
# !oumi evaluate -c "$tutorial_dir/eval.yaml"
# Out:
# @@@@@@@@@@@@@@@@@@@
# @                 @
# @   @@@@@  @  @   @
# @   @   @  @  @   @
# @   @@@@@  @@@@   @
# @                 @
# @   @@@@@@@   @   @
# @   @  @  @   @   @
# @   @  @  @   @   @
# @                 @
# @@@@@@@@@@@@@@@@@@@
#
# 2025-01-30 15:45:42.324934: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738251942.344887   34929 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738251942.350958   34929 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [2025-01-30 15:45:46,398][oumi][rank0][pid:34929][MainThread][INFO]][model_params.py:225] Found LoRA adapter at finetuning_tutorial/output, setting `adapter_model` to `model_name`.
# [2025-01-30 15:45:46,398][oumi][rank0][pid:34929][MainThread][INFO]][model_params.py:242] Setting `model_name` to HuggingFaceTB/SmolLM2-360M-Instruct found in adapter config.
# INFO 01-30 15:45:50 __init__.py:183] Automatically detected platform cuda.
# [2025-01-30 15:45:52,752][oumi][rank0][pid:34929][MainThread][INFO]][lm_harness.py:81] Loading adapter for eval: finetuning_tutorial/output
# [2025-01-30 15:45:52,862][oumi][rank0][pid:34929][MainThread][INFO]][lm_harness.py:110] Starting evaluation...
# [2025-01-30 15:45:52,862][oumi][rank0][pid:34929][MainThread][INFO]][lm_harness.py:111] 	LM Harness `model_params`:
# {'device_map': 'auto',
#  'dtype': torch.bfloat16,
#  'parallelize': False,
#  'peft': 'finetuning_tutorial/output',
#  'pretrained': 'HuggingFaceTB/SmolLM2-360M-Instruct',
#  'trust_remote_code': False}
# [2025-01-30 15:45:52,862][oumi][rank0][pid:34929][MainThread][INFO]][lm_harness.py:112] 	LM Harness `task_params`:
# LMHarnessTaskParams(evaluation_platform='lm_harness',
#                     task_name='mmlu_college_computer_science',
#                     num_samples=None,
#                     eval_kwargs={},
#                     num_fewshot=None)
# INFO:lm-eval:Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# INFO:lm-eval:Initializing hf model, with arguments: {'pretrained': 'HuggingFaceTB/SmolLM2-360M-Instruct', 'trust_remote_code': False, 'parallelize': False, 'dtype': torch.bfloat16, 'device_map': 'auto', 'peft': 'finetuning_tutorial/output'}
# INFO:lm-eval:Using device 'cuda:0'
# INFO:lm-eval:Model parallel was set to False.
# README.md: 100% 1.11k/1.11k [00:00<00:00, 6.50MB/s]
# mmlu_no_train.py: 100% 5.86k/5.86k [00:00<00:00, 34.4MB/s]
# data.tar: 100% 166M/166M [00:00<00:00, 190MB/s]
# Generating test split: 100 examples [00:00, 1034.59 examples/s]
# Generating validation split: 11 examples [00:00, 2724.86 examples/s]
# Generating dev split: 5 examples [00:00, 51.42 examples/s]
# INFO:lm-eval:Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:00<00:00, 703.83it/s]
# INFO:lm-eval:Running loglikelihood requests
# Running loglikelihood requests:   0% 0/400 [00:00<?, ?it/s]Passed argument batch_size = auto:1. Detecting largest batch size
# Determined largest batch size: 64
# Running loglikelihood requests: 100% 400/400 [00:37<00:00, 10.60it/s]
# fatal: not a git repository (or any of the parent directories): .git
# [2025-01-30 15:46:50,488][oumi][rank0][pid:34929][MainThread][INFO]][lm_harness.py:132] mmlu_college_computer_science's metric dict is {'acc,none': 0.24,
#  'acc_stderr,none': 0.04292346959909284,
#  'alias': 'college_computer_science'}

# %% [markdown]
# ## Use the Fine-tuned Model
#
# Once we're happy with the results, we can serve the fine-tuned model for interactive inference:

# %%
# %%writefile $tutorial_dir/trained_infer.yaml
#
# model:
#   model_name: "HuggingFaceTB/SmolLM2-360M-Instruct"
#   adapter_model: "finetuning_tutorial/output"
#   trust_remote_code: true
#   torch_dtype_str: "bfloat16"
#
# generation:
#   max_new_tokens: 2048
#   batch_size: 1
# Out:
# Overwriting finetuning_tutorial/trained_infer.yaml

# %%
from oumi.core.configs import InferenceConfig
from oumi.infer import infer

config = InferenceConfig.from_yaml(str(Path(tutorial_dir) / "trained_infer.yaml"))

input_text = (
    "Write a Python function to implement the quicksort algorithm. "
    "Please include comments explaining each step."
)

results = infer(config=config, inputs=[input_text])

print(results[0])
# Out:
# [2025-01-30 16:06:55,492][oumi][rank0][pid:16046][MainThread][WARNING]][infer.py:19] No inference engine specified. Using the default 'native' engine.
# [2025-01-30 16:06:55,494][oumi][rank0][pid:16046][MainThread][INFO]][models.py:185] Building model using device_map: auto (DeviceRankInfo(world_size=1, rank=0, local_world_size=1, local_rank=0))...
# [2025-01-30 16:06:55,496][oumi][rank0][pid:16046][MainThread][INFO]][models.py:255] Using model class: <class 'transformers.models.auto.modeling_auto.AutoModelForCausalLM'> to instantiate model.
# [2025-01-30 16:06:56,992][oumi][rank0][pid:16046][MainThread][INFO]][models.py:236] Loading PEFT adapter from: finetuning_tutorial/output ...
# [2025-01-30 16:06:58,005][oumi][rank0][pid:16046][MainThread][INFO]][native_text_inference_engine.py:111] Setting EOS token id to `2`
# conversation_id=None messages=[USER: Write a Python function to implement the quicksort algorithm. Please include comments explaining each step., ASSISTANT: ```python
# # Import the quicksort algorithm from the huggingface/huggingface-python-utils package
# from huggingface.huggingface_utils import quicksort
#
# # Define the quicksort function
# def quicksort(arr):
#     # Base case: if the array is empty or contains only one element, return it
#     if len(arr) <= 1:
#         return arr
#
#     # Choose a pivot element
#     pivot_index = quicksort(arr[0:len(arr)//2])
#     pivot = arr[len(arr)//2]
#
#     # Partition the array around the pivot
#     for i in range(len(arr)):
#         if arr[i] < pivot:
#             arr[i], arr[len(arr)//2] = quicksort(arr[i:len(arr)//2])
#             arr[len(arr)//2], arr[i] = arr[i], arr[len(arr)//2]
#
#     # Recursively sort the subarrays
#     return arr[0:len(arr)//2] + quicksort(arr[len(arr)//2:])
#
# # Example usage:
# arr = [5, 2, 8, 1, 9, 3, 6, 4]
# print("Original array:", arr)
# print("Sorted array:", quicksort(arr))
# ```
#
# This quicksort function implements the standard quicksort algorithm, which is a divide-and-conquer algorithm that recursively partitions an array around a pivot element. The function takes an array as input and returns a sorted array.
#
# Here's a brief explanation of the steps:
#
# 1.  **Base case**: If the array is empty or contains only one element, it is already sorted, so we can return it directly.
# 2.  **Choose a pivot**: We select a pivot element from the array, which can be any element other than the first or last element.
# 3.  **Partition**: We partition the array around the pivot by swapping elements that are less than the pivot with elements that are greater than the pivot.
# 4.  **Recursive case**: We recursively sort the subarrays on the left and right of the pivot.
# 5.  **Return**: We return the sorted subarrays.
#
# The quicksort function uses the `quicksort` function from the `huggingface/huggingface-python-utils` package, which provides a high-level interface for implementing the quicksort algorithm.
#
# Note: This implementation uses a simple recursive approach to sort the array. For more efficient implementations, consider using a divide-and-conquer approach or using a different sorting algorithm, such as merge sort or insertion sort.] metadata={}

# %%
def quicksort(arr):
    # Base case: if the array is empty or contains only one element, return it
    if len(arr) <= 1:
        return arr

    # Choose a pivot element
    pivot_index = quicksort(arr[0:len(arr)//2])
    pivot = arr[len(arr)//2]

    # Partition the array around the pivot
    for i in range(len(arr)):
        if arr[i] < pivot:
            arr[i], arr[len(arr)//2] = quicksort(arr[i:len(arr)//2])
            arr[len(arr)//2], arr[i] = arr[i], arr[len(arr)//2]

    # Recursively sort the subarrays
    return arr[0:len(arr)//2] + quicksort(arr[len(arr)//2:])

# Example usage:
arr = [5, 2, 8, 1, 9, 3, 6, 4]
print("Original array:", arr)
print("Sorted array:", quicksort(arr))
# Out:
# Original array: [5, 2, 8, 1, 9, 3, 6, 4]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-2879ec4acb53> in <cell line: 0>()
#      20 arr = [5, 2, 8, 1, 9, 3, 6, 4]
#      21 print("Original array:", arr)
# ---> 22 print("Sorted array:", quicksort(arr))
#
# <ipython-input-22-2879ec4acb53> in quicksort(arr)
#       5
#       6     # Choose a pivot element
# ----> 7     pivot_index = quicksort(arr[0:len(arr)//2])
#       8     pivot = arr[len(arr)//2]
#       9
#
# <ipython-input-22-2879ec4acb53> in quicksort(arr)
#      11     for i in range(len(arr)):
#      12         if arr[i] < pivot:
# ---> 13             arr[i], arr[len(arr)//2] = quicksort(arr[i:len(arr)//2])
#      14             arr[len(arr)//2], arr[i] = arr[i], arr[len(arr)//2]
#      15
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# Code generated gave out error, used Gemini to suggest fix. New code generated below.

# %%
def quicksort(arr):
    if len(arr) < 2:  # Base case: array with 0 or 1 element is already sorted
        return arr
    else:
        pivot = arr[0]  # Choose the first element as pivot
        less = [i for i in arr[1:] if i <= pivot]  # Elements less than or equal to pivot
        greater = [i for i in arr[1:] if i > pivot]  # Elements greater than pivot
        return quicksort(less) + [pivot] + quicksort(greater)  # Recursive calls and combining

# Example usage:
arr = [5, 2, 8, 1, 9, 3, 6, 4]
print("Original array:", arr)
print("Sorted array:", quicksort(arr))
# Out:
# Original array: [5, 2, 8, 1, 9, 3, 6, 4]
# Sorted array: [1, 2, 3, 4, 5, 6, 8, 9]
